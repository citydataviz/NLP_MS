# %% [markdown]
# # Traditional NLP vs LLM in practice
#
# 1. Sentiment Classfication
# 2. Aspect-based Classification
# 3. Topic Modeling
#
# - Data: restaurant review

# %%
# Install necesarry libraries
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: gensim in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 2)) (4.3.3)
# Requirement already satisfied: nltk in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 3)) (3.9.1)
# Requirement already satisfied: ollama in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: pandas in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 5)) (2.0.3)
# Requirement already satisfied: pyLDAvis in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: scikit-learn in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 7)) (1.5.2)
# Requirement already satisfied: filelock in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (18.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (4.67.0)
# Requirement already satisfied: xxhash in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (2024.10.0)
# Requirement already satisfied: aiohttp in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (3.11.3)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: packaging in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from gensim->-r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from gensim->-r requirements.txt (line 2)) (7.1.0)
# Requirement already satisfied: click in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from nltk->-r requirements.txt (line 3)) (8.1.7)
# Requirement already satisfied: joblib in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from nltk->-r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from nltk->-r requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: httpx>=0.27 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from ollama->-r requirements.txt (line 4)) (0.27.2)
# Requirement already satisfied: pydantic>=2.9 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from ollama->-r requirements.txt (line 4)) (2.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pandas->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pandas->-r requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pandas->-r requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: jinja2 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pyLDAvis->-r requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: numexpr in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pyLDAvis->-r requirements.txt (line 6)) (2.10.2)
# Requirement already satisfied: funcy in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pyLDAvis->-r requirements.txt (line 6)) (2.0)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from pyLDAvis->-r requirements.txt (line 6)) (58.0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets->-r requirements.txt (line 1)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets->-r requirements.txt (line 1)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from multidict<7.0,>=4.5->aiohttp->datasets->-r requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: idna>=2.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: anyio in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama->-r requirements.txt (line 4)) (4.6.2.post1)
# Requirement already satisfied: certifi in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama->-r requirements.txt (line 4)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama->-r requirements.txt (line 4)) (1.0.7)
# Requirement already satisfied: sniffio in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx>=0.27->ollama->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama->-r requirements.txt (line 4)) (2.23.4)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: wrapt in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from smart-open>=1.8.1->gensim->-r requirements.txt (line 2)) (1.17.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from anyio->httpx>=0.27->ollama->-r requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/adfz088/Library/Python/3.9/lib/python/site-packages (from jinja2->pyLDAvis->-r requirements.txt (line 6)) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - Read the Data

# %%
import pandas as pd
from datasets import load_dataset

# Load dataset & split
dataset    = load_dataset("tomaarsen/setfit-absa-semeval-restaurants")  # https://huggingface.co/datasets/tomaarsen/setfit-absa-semeval-restaurants
data       = dataset['train']             

df = pd.DataFrame(data)           
df.head()
# Out:
#                                                 text     span     label  \
# 0               But the staff was so horrible to us.    staff  negative
# 1  To be completely fair, the only redeeming fact...     food  positive
# 2  The food is uniformly exceptional, with a very...     food  positive
# 3  The food is uniformly exceptional, with a very...  kitchen  positive
# 4  The food is uniformly exceptional, with a very...     menu   neutral
#
#    ordinal
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# - Question: before training our model, anything to consider for this dataset?

# %%
# remove duplication rows of 'text' column 
df1 = df.drop_duplicates(subset=['text']).reset_index(drop=True)
len(df1)
# Out:
# 2019

# %% [markdown]
# # 1. Sentiment Classification

# %% [markdown]
# ### Traditional NLP

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import ollama
import random


texts      = df1['text']
labels_str = df1['label']

# 2. Convert string labels to integer encoding
le         = LabelEncoder()
labels     = le.fit_transform(labels_str)   # e.g. ['positive', ...] → [2, ...]

# 3. Train/test split (maintain distribution with stratify)
X_tr_txt, X_te_txt, y_tr, y_te = train_test_split(
    texts, labels,
    test_size=0.2,
    stratify=labels,
    random_state=42
)

# 4. Preprocessing: BOW & TF-IDF
vectorizers = {
    'bow':   CountVectorizer(max_features=5000, stop_words='english'),
    'tfidf': TfidfVectorizer(max_features=5000, stop_words='english')
}

X_tr, X_te = {}, {}
for name, vec in vectorizers.items():
    X_tr[name] = vec.fit_transform(X_tr_txt)
    X_te[name] = vec.transform(X_te_txt)

# 5. Initialize classifiers
models = {
    'naive_bayes':        MultinomialNB(),
    'logistic_regression': LogisticRegression(max_iter=1000),
    'random_forest':      RandomForestClassifier(n_estimators=100, random_state=42)
}

# 6. Training and evaluation (modified: only print failed predictions for Logistic Regression)
for vec_name, X_train in X_tr.items():
    print(f"\n--- {vec_name.upper()} Features ---")
    for model_name, clf in models.items():
        clf.fit(X_train, y_tr)
        preds = clf.predict(X_te[vec_name])
        acc   = accuracy_score(y_te, preds)
        print(f"{model_name:20s}  Accuracy: {acc:.4f}")
        print(classification_report(
            y_te, preds,
            target_names=le.classes_,
            zero_division=0
        ))

        # Only print mismatch samples for Logistic Regression
        if model_name == 'logistic_regression':
            mismatches = []
            for text, true_id, pred_id in zip(X_te_txt, y_te, preds):
                true_lbl = le.classes_[true_id]
                pred_lbl = le.classes_[pred_id]
                if pred_lbl != true_lbl:
                    mismatches.append((text, true_lbl, pred_lbl))

            print(f"\n--- {vec_name.upper()} + Logistic Regression Mismatches ---")
            for review, true_lbl, pred_lbl in mismatches:
                print(f"Review: {review}")
                print(f"True: {true_lbl:8s}  →  Pred: {pred_lbl}\n")
# Out:
# /Users/adfz088/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# --- BOW Features ---
# naive_bayes           Accuracy: 0.7050
#               precision    recall  f1-score   support
#
#     conflict       0.17      0.11      0.13        18
#     negative       0.60      0.52      0.56       161
#      neutral       0.59      0.38      0.46       127
#     positive       0.76      0.90      0.82       433
#
#     accuracy                           0.71       739
#    macro avg       0.53      0.48      0.49       739
# weighted avg       0.68      0.71      0.69       739
#
# logistic_regression   Accuracy: 0.7145
#               precision    recall  f1-score   support
#
#     conflict       0.25      0.11      0.15        18
#     negative       0.61      0.53      0.57       161
#      neutral       0.59      0.40      0.48       127
#     positive       0.77      0.90      0.83       433
#
#     accuracy                           0.71       739
#    macro avg       0.56      0.49      0.51       739
# weighted avg       0.69      0.71      0.70       739
#
#
# --- BOW + Logistic Regression Mismatches ---
# Review: The food was very good, but not very thai.
# True: conflict  →  Pred: positive
#
# Review: The food is alright - some stuff is good - some is not (like the steak dish which tends to be dry).
# True: negative  →  Pred: positive
#
# Review: They couldn't even make a salad that was appealing.
# True: negative  →  Pred: positive
#
# Review: I like the somosas, chai, and the chole, but the dhosas and dhal were kinda dissapointing.
# True: negative  →  Pred: positive
#
# Review: It's like they took leftover chicken, poured oil and sprinkled pepper powder over it (the sauce was translucent and red).
# True: neutral   →  Pred: negative
#
# Review: We started with lox and mussels (the best ive ever had, ever) and had the cod and trout for dinner.
# True: neutral   →  Pred: positive
#
# Review: The food was so-so.
# True: neutral   →  Pred: positive
#
# Review: After 2 tries by the waiter to take it away (we hadn't even looked at it yet, we had full beers yet to drink), the manager approached and told us they needed the table for people with reservations.
# True: positive  →  Pred: negative
#
# Review: Although they do the typical what kind of water would you like questions the service was good and overall very relaxing to place to eat.
# True: positive  →  Pred: neutral
#
# Review: I would definitely go back for a very special occasion, but not for regular fine dining.
# True: neutral   →  Pred: positive
#
# Review: I recently went to this restaurant with some co-workers for lunch and had an amazing time.
# True: neutral   →  Pred: positive
#
# Review: I really liked the noodle dishes at Rice Avenue compared to their Green Curry dish.
# True: positive  →  Pred: negative
#
# Review: The place was real empty but that was because this was the first Sunday they ever opened.
# True: negative  →  Pred: positive
#
# Review: In fact, while leaving the place we saw two people looking at the menu, and I couldn't help telling them that the food was horrible.
# True: negative  →  Pred: neutral
#
# Review: While this isn't classical restaurant fare, the chef has given new life to an old cuisine with some really innovative and tasty dishes that are genuinely Indian without being heavy or same old restaurant burn-outs.
# True: neutral   →  Pred: positive
#
# Review: After a seafood craving, i checked citysearch and chose to go to Fish based on a previous review and the citysearch info.
# True: neutral   →  Pred: positive
#
# Review: Their sake list was extensive, but we were looking for Purple Haze, which wasn't listed but made for us upon request!
# True: conflict  →  Pred: positive
#
# Review: My husband said the portions were very small, but if my main course was good to eat the portion would've been fine for me.
# True: positive  →  Pred: negative
#
# Review: They might be all business at the counter when you give your order, but their food says I love you.
# True: positive  →  Pred: negative
#
# Review: We got a little tipsy from the sake but isn't that what Saturday nights with the girlfriends are all about?
# True: neutral   →  Pred: positive
#
# Review: I went with 5 friends and we lingered at the table for a bit and didn't feel rushed at all even though there was a wait.
# True: negative  →  Pred: neutral
#
# Review: The service varys from day to day- sometimes they're very nice, and sometimes not.
# True: conflict  →  Pred: positive
#
# Review: A narrow corridor leads to a tiny space where there are three tiny white tiled counters, a great deal of mess (stacks of bottles, cans) and a small counter holding 12-14 entrees.
# True: neutral   →  Pred: negative
#
# Review: I was back-to-back with the diner at the table behind me and wait staff had to hoist trays over our heads as they squeezed past us again and again.
# True: neutral   →  Pred: negative
#
# Review: The Italian food has flavor (that can be sort of surprising on the UES), and the service turns from a nightmare to attentive,they sort of remind me of the NY Yankees of the late 90's, no matter how bad it look, you knew that there was a rally just around the corner...
# True: positive  →  Pred: conflict
#
# Review: The makhani was OK --the korma was bland.
# True: negative  →  Pred: neutral
#
# Review: The whole set up is truly unprofessional and I wish Cafe Noir would get some good staff, because despite the current one this is a great place.
# True: negative  →  Pred: positive
#
# Review: Some servers make you feel like they are doing you a favor to bring you the food.
# True: negative  →  Pred: neutral
#
# Review: When we were finally seated our waitress came by twice-1 for our order and 2-for our check.
# True: neutral   →  Pred: negative
#
# Review: While the food was good (certainly no Il Mulino) the service was horrendous.
# True: negative  →  Pred: positive
#
# Review: The dim sum servings here are a bit larger than I'm used to.
# True: neutral   →  Pred: negative
#
# Review: The fillings may be unconventional but the dosa batter is definitely authentic and the combinations very tasty.
# True: positive  →  Pred: neutral
#
# Review: Waiters are slow but sweet.
# True: conflict  →  Pred: negative
#
# Review: Granted the space is smaller than most, it is the best service you will find in even the largest of restaurants.
# True: positive  →  Pred: negative
#
# Review: All the money went into the interior decoration, none of it went to the chefs.
# True: positive  →  Pred: negative
#
# Review: Staffs are not that friendly, but the taste covers all.
# True: negative  →  Pred: positive
#
# Review: The food was just OK, at least for what food was available.
# True: negative  →  Pred: neutral
#
# Review: Well, this place is so Ghetto its not even funny.
# True: negative  →  Pred: positive
#
# Review: Thalia is a beautiful restaurant with beautiful people serving you, but the food doesn't quite match up.
# True: negative  →  Pred: positive
#
# Review: They are often crowded on the weekends but they are efficient and accurate with their service.
# True: positive  →  Pred: negative
#
# Review: Yes, they use fancy ingredients, but even fancy ingredients don't make for good pizza unless someone knows how to get the crust right.
# True: negative  →  Pred: positive
#
# Review: At the end you're left with a mild broth with noodles that you can slurp out of a cup.
# True: positive  →  Pred: neutral
#
# Review: So I've never actually been to M proper, but I've had it delivered a few times.
# True: neutral   →  Pred: negative
#
# Review: But after last night, Spice Grill is the only place I'm eating indian cuisine.
# True: positive  →  Pred: neutral
#
# Review: The staff is excellent, specjal: that girl behind the bar, european chic.
# True: neutral   →  Pred: positive
#
# Review: at night, but it's hard to hear your own conversation with everyone else competing for that same luxury - the music playing in the background is also voluminous.
# True: negative  →  Pred: positive
#
# Review: The steak was very fatty and the sauce was overpowering and not very tasty.
# True: negative  →  Pred: positive
#
# Review: The food however, is what one might expect.
# True: neutral   →  Pred: positive
#
# Review: Prices are higher to dine in and their chicken tikka marsala is quite good.
# True: negative  →  Pred: positive
#
# Review: All the desserts the group tried got favorable reviews.
# True: positive  →  Pred: negative
#
# Review: The waitstaff are all very busy, it's not outstanding service, but I've never been dealt with rudely.
# True: negative  →  Pred: conflict
#
# Review: Hats off to the chef.
# True: positive  →  Pred: negative
#
# Review: Not a large place, but it's cute and cozy.
# True: conflict  →  Pred: positive
#
# Review: Their wines by the glass are a great accompaniment and you can eat like a king with wine for under $30.
# True: positive  →  Pred: neutral
#
# Review: Went to Ottimo and was expecting outstanding pizza (as I love La Pizza Fresca).
# True: neutral   →  Pred: positive
#
# Review: Our waiter was fine, the place looks nice in that not-trying-too-hard way, but at those prices, a little more should be expected of your food.
# True: negative  →  Pred: positive
#
# Review: 20 minutes for our reservation but it gave us time to have a few cocktails and enjoy our surroundings and each other.
# True: negative  →  Pred: positive
#
# Review: After we got our sashimi order, I could not believe how small the portions were!
# True: neutral   →  Pred: negative
#
# Review: Also, specify if you like your food spicy- its rather bland if you don't.
# True: neutral   →  Pred: negative
#
# Review: I didn't take a look at the rest menu, but the oysters were fantastic.
# True: neutral   →  Pred: positive
#
# Review: The fish is fresh but the variety of fish is nothing out of ordinary.
# True: negative  →  Pred: positive
#
# Review: First of all, this place is *not* romantic, as claimed by Citysearch's editorial review.
# True: negative  →  Pred: positive
#
# Review: Looking around, I saw a room full of New Yorkers enjoying a real meal in a real restaurant, not a clubhouse of the fabulous trying to be seen.
# True: neutral   →  Pred: positive
#
# Review: The Pad thai, lad nar and various other dishes all look good on paper but, I've had better thai food in less asthetically pleasing places.
# True: neutral   →  Pred: conflict
#
# Review: Don't dine at Tamarind for the vegetarian dishes, they are simply not up to par with the non-veg selections.
# True: negative  →  Pred: positive
#
# Review: Not worth the prices.
# True: negative  →  Pred: positive
#
# Review: We had a party in their private room and they made it truly memorable and were very helpful in the planning.
# True: neutral   →  Pred: positive
#
# Review: Ess-A-Bagel (either by Sty-town or midtown) is by far the best bagel in NY.
# True: positive  →  Pred: neutral
#
# Review: instead ordered an ice cold beer which to me works with indian.
# True: positive  →  Pred: neutral
#
# Review: We were seated outside and the waiter spilled red wine and hot tea on myself and my date.
# True: negative  →  Pred: neutral
#
# Review: The only concern i have is with the slighly all-business waitstaff who order and throw the food down, rushing you out.
# True: negative  →  Pred: neutral
#
# Review: Our agreed favorite is the orrechiete with sausage and chicken (usually the waiters are kind enough to split the dish in half so you get to sample both meats).
# True: positive  →  Pred: neutral
#
# Review: The sweet lassi was excellent as was the lamb chettinad and the garlic naan but the rasamalai was forgettable.
# True: negative  →  Pred: positive
#
# Review: During our meal, the management came over and checked on us and even bought us a round of drinks.
# True: neutral   →  Pred: positive
#
# Review: Still, any quibbles about the bill were off-set by the pour-your-own measures of liquers which were courtesey of the house...
# True: positive  →  Pred: conflict
#
# Review: Consequently, their burgers fell apart in their hands and made such a mess that they did'nt feel like finishing them.
# True: negative  →  Pred: positive
#
# Review: We figured we never had Argentinian Pizza before so we grabbed our lunch there, sharing a large Pelligrino, a pizza of two of their specials, one was goat cheese the other blue cheese, and both were excellent.
# True: neutral   →  Pred: positive
#
# Review: They are served with a free appetizer and the portions are perfect for lunch.
# True: neutral   →  Pred: positive
#
# Review: Service was very prompt but slightly rushed.
# True: conflict  →  Pred: positive
#
# Review: We won't go to this place again for a good meal.
# True: negative  →  Pred: positive
#
# Review: This is one great place to eat pizza more out but not a good place for take-out pizza.
# True: negative  →  Pred: positive
#
# Review: The dish had like 6 pieces of beef in it.
# True: neutral   →  Pred: negative
#
# Review: Here's to the fake fish tanks too...
# True: negative  →  Pred: positive
#
# Review: The dim sum here is only so-so.
# True: neutral   →  Pred: positive
#
# Review: Overall the restaurant is more expensive than our other sushi favorites, but everything was delicious.
# True: neutral   →  Pred: positive
#
# Review: The service is spotty, sometimes really friendly and sometimes barely there.
# True: conflict  →  Pred: positive
#
# Review: The atmosphere isn't the greatest , but I suppose that's how they keep the prices down .
# True: positive  →  Pred: neutral
#
# Review: (food was delivered by a busboy, not waiter) We got no cheese offered for the pasta, our water and wine glasses remained EMPTY our entire meal, when we would have easily spent another $20 on wine.
# True: neutral   →  Pred: negative
#
# Review: Anyways, if you're in the neighborhood to eat good food, I wouldn't waste my time trying to find something, rather go across the street to Tamari.
# True: positive  →  Pred: negative
#
# Review: I have never before eaten 40 pieces of relatively good nigiri.
# True: neutral   →  Pred: negative
#
# Review: I've had the lunch buffet at Chennai a couple of times, when I have been in the neighborhood.
# True: neutral   →  Pred: positive
#
# Review: The entertainment was great they have shows that go on through out the dinner.
# True: neutral   →  Pred: positive
#
# Review: When we notified him that he didn't mention the specials, he didn't apologize but let us know that we made a very good decision regardless.
# True: neutral   →  Pred: positive
#
# Review: The two star chefs left quite some time ago to open their own place.
# True: neutral   →  Pred: negative
#
# Review: Overall, I'm still impressed that the place even exists and the prices are quite decent but then again, its Chinatown.
# True: positive  →  Pred: neutral
#
# Review: I was in love with Pongsri on 48th, but compared to Suan it is slow in service and overpriced.
# True: negative  →  Pred: positive
#
# Review: We were still sitting at the bar while we drank the sangria, but facing away from the bar when we turned back around, the $2 was gone the people next to us said the bartender took it.
# True: negative  →  Pred: neutral
#
# Review: Average to good Thai food, but terrible delivery.
# True: positive  →  Pred: negative
#
# Review: Have always found that the waiters will go out of their way to be helpful, despite the fact they are often busy with lots of diners.
# True: neutral   →  Pred: positive
#
# Review: I can't believe people complain about no cheese sticks?
# True: neutral   →  Pred: negative
#
# Review: great place to go for a drink too because they have 100 kinds of beer.
# True: neutral   →  Pred: positive
#
# Review: I would never wait for a table to eat, it just is not THAT great.
# True: neutral   →  Pred: positive
#
# Review: Definitely not worth the price!
# True: negative  →  Pred: positive
#
# Review: We ordered a tuna melt - it came with out cheese which just made it a tuna sandwich.
# True: neutral   →  Pred: negative
#
# Review: However, I was there for a work dinner not long ago when my colleague from London noticed a very large waterbug on the ceiling.
# True: neutral   →  Pred: negative
#
# Review: We actually gave 10% tip (which we have never done despite mediocre food and service), because we felt totally ripped off.
# True: neutral   →  Pred: negative
#
# Review: Hopefully next time, I will save room for dessert.
# True: neutral   →  Pred: positive
#
# Review: The only disappointment was the coat check girls who didn't seem to know what a customer is on a realtively non-busy night (for the coat check girls).
# True: negative  →  Pred: neutral
#
# Review: This place is not worth the prices.
# True: negative  →  Pred: positive
#
# Review: The service was impeccable and unobtrusive -- the staff knows what they are there to do -- to know their menu, present your meal, and attend to your needs.
# True: positive  →  Pred: neutral
#
# Review: While the new restaurant still features much of the same classical furniture that made Tiffin so attractive, the menu has been overhauled.
# True: positive  →  Pred: negative
#
# Review: Worse of all, $60 was erroneously added to our $80 bill.
# True: negative  →  Pred: positive
#
# Review: Service was decent, but not as smooth as I would expect from a place with these prices and reputation.
# True: negative  →  Pred: positive
#
# Review: The service was a bit slow, but they were very friendly.
# True: negative  →  Pred: positive
#
# Review: The steak was very fatty and the sauce was overpowering and not very tasty.
# True: negative  →  Pred: positive
#
# Review: Only complaint would be that at an average cost of $12-$15 per meal, I'd like not to have to worry about finding a seat!
# True: neutral   →  Pred: negative
#
# Review: The food is very good too but for the most part, it's just regular food, nothing special.
# True: neutral   →  Pred: positive
#
# Review: No food snobs allowed, this place is for people who appreciate good food.
# True: neutral   →  Pred: positive
#
# Review: The prices are about $9 for an entree for dinner and even less for lunch.
# True: positive  →  Pred: neutral
#
# Review: Service is friendly, prices are good - delivery time was a little slow, but for the way this pizza tastes, I'm willing to overlook it.
# True: negative  →  Pred: positive
#
# Review: It's the perfect restaurant for NY life style, it got cool design, awsome drinks and food and lot's of good looking people eating and hanging at the pink bar...
# True: neutral   →  Pred: positive
#
# Review: Service is not exactly five star, but thats not really a big deal.
# True: conflict  →  Pred: positive
#
# Review: Their bagels are fine, but they are a little overcooked, and not really a 'special' bagel experience.
# True: conflict  →  Pred: neutral
#
# Review: - the bread at the beginning is super tasty and makes you want more - the pizza is delicious and comes in personal sizes, however be warned that the Peter's Favourite pizza with prosciutto and baby arugula is actually a margarite pizza with cold prosciutto and baby arugula on top, like a salad.
# True: positive  →  Pred: neutral
#
# Review: The food is uniformly exceptional, with a very capable kitchen which will proudly whip up whatever you feel like eating, whether it's on the menu or not.
# True: neutral   →  Pred: positive
#
# Review: We were disappointed with the pre-fixe menu of only 2 choices per course (other restaurants offer 3 choices) and ended up ordering a la carte.
# True: neutral   →  Pred: negative
#
# Review: The dish had like 6 pieces of beef in it.
# True: neutral   →  Pred: negative
#
# Review: in an effort to increase turnover, the restaurant offers no desserts beyond the complimentary espresso cup filled with chocolate mousse.
# True: negative  →  Pred: positive
#
# Review: There are a few Italian employees who may not speak the best English but for me that adds to the experience.
# True: conflict  →  Pred: positive
#
# Review: I care more about the food and ambience.
# True: neutral   →  Pred: positive
#
# Review: The Dim Sum was so-so, but not spectacular.
# True: neutral   →  Pred: positive
#
# Review: Late nite omelletes are not good here, there is no variety!
# True: negative  →  Pred: positive
#
# Review: The server was really cool and served us our food and drinks with a smile.
# True: positive  →  Pred: neutral
#
# Review: The plain pizza was soggy and the creative wild mushroom(third generation-Fornini) pizza we had was drenched with truffle oil in the middle( again making it soggy) and nothingon the rest.
# True: positive  →  Pred: negative
#
# Review: My entree of hot pot with seafood was full of imitation crabmeat with a couple pieces of shrimp and squid, and was unnecessarily heated with a burner.
# True: positive  →  Pred: negative
#
# Review: It is far more popular as a bar than as a restaurant, with only a few tables and the waiter being the bartender, but we greatly enjoyed the unobtrusive atmosphere.
# True: positive  →  Pred: neutral
#
# Review: The food itself was just ok - nothing spectacular - but the service was awful.
# True: negative  →  Pred: neutral
#
# Review: The ambience was nice, but service wasn't so great.
# True: negative  →  Pred: positive
#
# Review: Stick to dimsum, not super overpriced noodles.
# True: positive  →  Pred: neutral
#
# Review: The puke green walls leave a lot to be desired, but the food is very good.
# True: negative  →  Pred: positive
#
# Review: Though the Spider Roll may look like a challenge to eat, with soft shell crab hanging out of the roll, it is well worth the price you pay for them.
# True: conflict  →  Pred: positive
#
# Review: Price no more than a Jersey deli but way better.
# True: positive  →  Pred: negative
#
# Review: The only disappointment was the coat check girls who didn't seem to know what a customer is on a realtively non-busy night (for the coat check girls).
# True: negative  →  Pred: neutral
#
# Review: Even with a relatively inexpensive botle of wine, if you can call $70.00 inexpensive, the cost is through the roof for better than average fare.
# True: negative  →  Pred: conflict
#
# Review: First, the waiter who served us neglected to fill us in on the specials, which I would have chosen had I known about them.
# True: negative  →  Pred: positive
#
# Review: The location and ambience is Ok but the food is what makes up for it.
# True: positive  →  Pred: neutral
#
# Review: The food can get pricey but the prixe fixe tasting menu is the greatest food for a good price and they cater the food to any food allergies or food you don't like.
# True: neutral   →  Pred: positive
#
# Review: The only fallback on this restaurant is the prices.
# True: negative  →  Pred: positive
#
# Review: My biggest complaint was the un-tasty food although presented well.
# True: conflict  →  Pred: positive
#
# Review: We got in line and were served while in line a bannan fritter.
# True: neutral   →  Pred: negative
#
# Review: Ive been here so many times the waiters know my name.
# True: neutral   →  Pred: positive
#
# Review: Until you realize that their five minutes is meaningless and your wait may be anywhere from two to twenty minutes it may be frustrating.
# True: negative  →  Pred: positive
#
# Review: No free drink.
# True: neutral   →  Pred: positive
#
# Review: Great roofdeck, nice group of 30 somethings, but no music, kind of quiet.
# True: positive  →  Pred: negative
#
# Review: The menu choices are similar but the taste lacked more flavor than it looked.
# True: neutral   →  Pred: negative
#
# Review: It's a shame that a nice, convenient place like the Pink Pony can be so ruined by lousy service.
# True: positive  →  Pred: negative
#
# Review: skip dessert.
# True: negative  →  Pred: positive
#
# Review: They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# True: neutral   →  Pred: negative
#
# Review: They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# True: neutral   →  Pred: negative
#
# Review: Perhaps this food is considered extreme to an Upper East Side resident, but for the rest of us who've actually eaten ethnic food, this is simply dull.
# True: negative  →  Pred: conflict
#
# Review: It can be a little confusing as to where one goes to order, but once the food is ordered, you are in for a treat.
# True: positive  →  Pred: neutral
#
# Review: I've had to wait only a few times during lunch but this place is definitely worth the wait.
# True: neutral   →  Pred: positive
#
# Review: The first 2 courses were very good, but the chocolate sampler was too rich for me and the dessert wine far too sweet.
# True: negative  →  Pred: positive
#
# Review: While the $20 entree range is not overly expensive, in New York City, there is definitely better food in that range, and so Sapphire, despite it's lovely atmosphere, will most likely not be a restaurant to which I will return.
# True: negative  →  Pred: positive
#
# Review: To my right, the hostess stood over a busboy and hissed rapido, rapido as he tried to clear and re-set a table for six.
# True: neutral   →  Pred: negative
#
# Review: Plus, when our entrees were held up in the kitchen on a busy Saturday night, the owner sent over complimentary summer rolls to hold us over!
# True: negative  →  Pred: positive
#
# Review: The place is small and intimate and you may feel a little crowded, but the service is excellent and it's great for friends out, a romantic date, or a special occassion.
# True: negative  →  Pred: positive
#
# Review: While the ambiance and atmosphere were great, the food and service could have been a lot better.
# True: negative  →  Pred: positive
#
# Review: Owner must have coem on this website to give himself credit.
# True: neutral   →  Pred: positive
#
# Review: I noted it was crossed off on the bill.
# True: neutral   →  Pred: positive
#
# Review: And the bill was outragous.
# True: negative  →  Pred: positive
#
# Review: While the place is not a hotspot hangout, the drinks are unique and pack a lot of bang for the buck.
# True: negative  →  Pred: positive
#
# Review: The service was mediocre, and the lack of air conditioning made for a less than comfortable meal.
# True: neutral   →  Pred: negative
#
# Review: They wouldnt even let me finish my glass of wine before offering another.
# True: neutral   →  Pred: positive
#
# Review: The bread is the soft paratha bread (unlike the plain bread they use in Calcutta), and the stuffing is tandoori styled and very flavorful.
# True: negative  →  Pred: positive
#
# Review: The first time I went, and was completely taken by the live jazz band and atmosphere, I ordered the Lobster Cobb Salad.
# True: positive  →  Pred: neutral
#
# Review: Yes, the prices are high, but I felt it was worth it.
# True: conflict  →  Pred: negative
#
# Review: I have eaten at Saul, many times, the food is always consistently, outrageously good.
# True: positive  →  Pred: neutral
#
# Review: Our server checked on us maybe twice during the entire meal.
# True: neutral   →  Pred: negative
#
# Review: Plain and simple it's bad thai food.
# True: negative  →  Pred: positive
#
# Review: My friend's food was also the complete opposite of what it's supposed to taste like (aND look like).
# True: negative  →  Pred: positive
#
# Review: While Sapphire is certainly not lacking in ambiance, and probably has the best decor of any Indian restaurant I have been to in New York City, the food was not what I had hoped for.
# True: negative  →  Pred: positive
#
# Review: I must warn the reader that the portions sizes are very small (especially the appetizers), so if you plan to eat until you are full and do not intend to order the chef's special tasting menu, prepare to order and pay for an appetizer (1 dish for each person because the portions are not for sharing), a main entree, and the cold udon at the end of the meal.
# True: neutral   →  Pred: negative
#
# Review: They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# True: neutral   →  Pred: negative
#
# Review: This place is really trendi but they have forgotten about the most important part of a  restaurant, the food.
# True: negative  →  Pred: positive
#
# Review: Unlike other places in NYC where the sandwiches you want only come as a triple-decker, here you can get what you want in a reasonably-sized portion (and price).
# True: negative  →  Pred: positive
#
# Review: So some of the reviews here are accurate about the crowd and noise.
# True: negative  →  Pred: positive
#
# Review: So some of the reviews here are accurate about the crowd and noise.
# True: negative  →  Pred: positive
#
# Review: if this happens, just ask for real naan.
# True: neutral   →  Pred: negative
#
# Review: The food is alright - some stuff is good - some is not (like the steak dish which tends to be dry).
# True: conflict  →  Pred: positive
#
# Review: A gentleman, maybe the manager, came to our table, and without so much as a smile or greeting asked for our order.
# True: neutral   →  Pred: negative
#
# Review: It's super-trendy and there's always someone to take that empty seat, so it seems that customer service has been deemed not of the essence.
# True: neutral   →  Pred: positive
#
# Review: They are served with a free appetizer and the portions are perfect for lunch.
# True: neutral   →  Pred: positive
#
# Review: Monday nights are a bargain at the $28 prix fix - this includes a three course meal plus *three* glasses of wine paired with each course.
# True: neutral   →  Pred: positive
#
# Review: Won't or Can't is not in the service directory.
# True: positive  →  Pred: negative
#
# Review: Although the tables may be closely situated, the candle-light, food-quality and service overcompensate.
# True: negative  →  Pred: positive
#
# Review: (food was delivered by a busboy, not waiter) We got no cheese offered for the pasta, our water and wine glasses remained EMPTY our entire meal, when we would have easily spent another $20 on wine.
# True: neutral   →  Pred: negative
#
# Review: We got in line and were served while in line a bannan fritter.
# True: neutral   →  Pred: negative
#
# Review: While the room is not particularly comfortable, once you're seated you'll forget about everything except what's on your plate.
# True: negative  →  Pred: positive
#
# Review: The table service could have been a little more attentive but as someone who also works in the service industry, I understood they were busy.
# True: conflict  →  Pred: positive
#
# Review: When asked about how a certain dish was prepared in comparison to a similar at other thai restaurants, he replied this is not Mcdonald's, every place makes things differently While it is understandable that every place is indeed different, there was not a need to be uncourteous to customers and downright rude.
# True: neutral   →  Pred: negative
#
# Review: The food can get pricey but the prixe fixe tasting menu is the greatest food for a good price and they cater the food to any food allergies or food you don't like.
# True: conflict  →  Pred: positive
#
# Review: The crispy chicken wasn't for us, though.
# True: negative  →  Pred: positive
#
# Review: They used shredded cheese on top!
# True: neutral   →  Pred: negative
#
# Review: Not the greatest sushi place, but excellent for a $19.95 all you can eat.
# True: negative  →  Pred: positive
#
# Review: We didn't even see a menu, as our waiter described both the specials and the main dishes.
# True: positive  →  Pred: neutral
#
# Review: When my dessert came, there was a candle in it - not because anyone asked for one - but because the waiter must have seen me opening my birthday card and gift, and said he knew it was a special occassion of some sort.
# True: positive  →  Pred: neutral
#
# Review: Wait staff is blantently unappreciative of your business but its the best pie on the UWS!
# True: negative  →  Pred: positive
#
# Review: I ate here a week ago and found most dishes average at best and too expensive.
# True: negative  →  Pred: positive
#
# Review: Although they do the typical what kind of water would you like questions the service was good and overall very relaxing to place to eat.
# True: positive  →  Pred: neutral
#
# Review: I must warn the reader that the portions sizes are very small (especially the appetizers), so if you plan to eat until you are full and do not intend to order the chef's special tasting menu, prepare to order and pay for an appetizer (1 dish for each person because the portions are not for sharing), a main entree, and the cold udon at the end of the meal.
# True: positive  →  Pred: negative
#
# random_forest         Accuracy: 0.6942
#               precision    recall  f1-score   support
#
#     conflict       0.27      0.17      0.21        18
#     negative       0.63      0.48      0.55       161
#      neutral       0.54      0.36      0.43       127
#     positive       0.74      0.89      0.81       433
#
#     accuracy                           0.69       739
#    macro avg       0.55      0.48      0.50       739
# weighted avg       0.67      0.69      0.67       739
#
#
# --- TFIDF Features ---
# naive_bayes           Accuracy: 0.6536
#               precision    recall  f1-score   support
#
#     conflict       0.00      0.00      0.00        18
#     negative       0.64      0.30      0.41       161
#      neutral       0.63      0.09      0.16       127
#     positive       0.66      0.98      0.78       433
#
#     accuracy                           0.65       739
#    macro avg       0.48      0.34      0.34       739
# weighted avg       0.63      0.65      0.58       739
#
# logistic_regression   Accuracy: 0.7064
#               precision    recall  f1-score   support
#
#     conflict       0.00      0.00      0.00        18
#     negative       0.62      0.47      0.53       161
#      neutral       0.67      0.26      0.38       127
#     positive       0.73      0.96      0.83       433
#
#     accuracy                           0.71       739
#    macro avg       0.51      0.42      0.43       739
# weighted avg       0.68      0.71      0.66       739
#
#
# --- TFIDF + Logistic Regression Mismatches ---
# Review: The food was very good, but not very thai.
# True: conflict  →  Pred: positive
#
# Review: An excellent alternative to fast food joints and ordering in but, the food was slightly disappointing.
# True: negative  →  Pred: positive
#
# Review: The food is alright - some stuff is good - some is not (like the steak dish which tends to be dry).
# True: negative  →  Pred: positive
#
# Review: They couldn't even make a salad that was appealing.
# True: negative  →  Pred: positive
#
# Review: I like the somosas, chai, and the chole, but the dhosas and dhal were kinda dissapointing.
# True: negative  →  Pred: positive
#
# Review: It's like they took leftover chicken, poured oil and sprinkled pepper powder over it (the sauce was translucent and red).
# True: neutral   →  Pred: negative
#
# Review: We started with lox and mussels (the best ive ever had, ever) and had the cod and trout for dinner.
# True: neutral   →  Pred: positive
#
# Review: The food was so-so.
# True: neutral   →  Pred: positive
#
# Review: After 2 tries by the waiter to take it away (we hadn't even looked at it yet, we had full beers yet to drink), the manager approached and told us they needed the table for people with reservations.
# True: positive  →  Pred: negative
#
# Review: I would definitely go back for a very special occasion, but not for regular fine dining.
# True: neutral   →  Pred: positive
#
# Review: I recently went to this restaurant with some co-workers for lunch and had an amazing time.
# True: neutral   →  Pred: positive
#
# Review: The place was real empty but that was because this was the first Sunday they ever opened.
# True: negative  →  Pred: positive
#
# Review: In fact, while leaving the place we saw two people looking at the menu, and I couldn't help telling them that the food was horrible.
# True: negative  →  Pred: neutral
#
# Review: they were able to squeeze me in at 6 after i called the night before my anniversary for a friday night reservation and told me they'd treat us well for the occasion.
# True: neutral   →  Pred: positive
#
# Review: While this isn't classical restaurant fare, the chef has given new life to an old cuisine with some really innovative and tasty dishes that are genuinely Indian without being heavy or same old restaurant burn-outs.
# True: neutral   →  Pred: positive
#
# Review: After a seafood craving, i checked citysearch and chose to go to Fish based on a previous review and the citysearch info.
# True: neutral   →  Pred: positive
#
# Review: Their sake list was extensive, but we were looking for Purple Haze, which wasn't listed but made for us upon request!
# True: conflict  →  Pred: positive
#
# Review: The menu was impressive with selections ranging from a burger, to steak, to escargot.
# True: neutral   →  Pred: positive
#
# Review: The sushi is average and the prices are anything but.
# True: neutral   →  Pred: positive
#
# Review: We got a little tipsy from the sake but isn't that what Saturday nights with the girlfriends are all about?
# True: neutral   →  Pred: positive
#
# Review: I went with 5 friends and we lingered at the table for a bit and didn't feel rushed at all even though there was a wait.
# True: negative  →  Pred: neutral
#
# Review: The service varys from day to day- sometimes they're very nice, and sometimes not.
# True: conflict  →  Pred: positive
#
# Review: A narrow corridor leads to a tiny space where there are three tiny white tiled counters, a great deal of mess (stacks of bottles, cans) and a small counter holding 12-14 entrees.
# True: neutral   →  Pred: negative
#
# Review: I was back-to-back with the diner at the table behind me and wait staff had to hoist trays over our heads as they squeezed past us again and again.
# True: neutral   →  Pred: negative
#
# Review: The makhani was OK --the korma was bland.
# True: negative  →  Pred: neutral
#
# Review: The whole set up is truly unprofessional and I wish Cafe Noir would get some good staff, because despite the current one this is a great place.
# True: negative  →  Pred: positive
#
# Review: Some servers make you feel like they are doing you a favor to bring you the food.
# True: negative  →  Pred: positive
#
# Review: When we were finally seated our waitress came by twice-1 for our order and 2-for our check.
# True: neutral   →  Pred: negative
#
# Review: While the food was good (certainly no Il Mulino) the service was horrendous.
# True: negative  →  Pred: positive
#
# Review: The dim sum servings here are a bit larger than I'm used to.
# True: neutral   →  Pred: negative
#
# Review: Waiters are slow but sweet.
# True: conflict  →  Pred: positive
#
# Review: All the money went into the interior decoration, none of it went to the chefs.
# True: positive  →  Pred: neutral
#
# Review: Staffs are not that friendly, but the taste covers all.
# True: negative  →  Pred: positive
#
# Review: The food was just OK, at least for what food was available.
# True: negative  →  Pred: neutral
#
# Review: Well, this place is so Ghetto its not even funny.
# True: negative  →  Pred: positive
#
# Review: Thalia is a beautiful restaurant with beautiful people serving you, but the food doesn't quite match up.
# True: negative  →  Pred: positive
#
# Review: Yes, they use fancy ingredients, but even fancy ingredients don't make for good pizza unless someone knows how to get the crust right.
# True: negative  →  Pred: positive
#
# Review: A few tips: skip the turnip cake, roast pork buns and egg custards.
# True: negative  →  Pred: positive
#
# Review: So I've never actually been to M proper, but I've had it delivered a few times.
# True: neutral   →  Pred: negative
#
# Review: But after last night, Spice Grill is the only place I'm eating indian cuisine.
# True: positive  →  Pred: neutral
#
# Review: The staff is excellent, specjal: that girl behind the bar, european chic.
# True: neutral   →  Pred: positive
#
# Review: We only ordered desserts and drinks, but no refills were offered.
# True: neutral   →  Pred: negative
#
# Review: at night, but it's hard to hear your own conversation with everyone else competing for that same luxury - the music playing in the background is also voluminous.
# True: negative  →  Pred: positive
#
# Review: I ordered the crab cocktail and it was soaked in a lime juice concoction where all you could taste was the lime.
# True: neutral   →  Pred: positive
#
# Review: The steak was very fatty and the sauce was overpowering and not very tasty.
# True: negative  →  Pred: positive
#
# Review: If you like your music blasted and the system isnt that great and if you want to pay at least 100 dollar bottle minimun then you'll love it here.
# True: negative  →  Pred: positive
#
# Review: The food however, is what one might expect.
# True: neutral   →  Pred: negative
#
# Review: Prices are higher to dine in and their chicken tikka marsala is quite good.
# True: negative  →  Pred: positive
#
# Review: All the desserts the group tried got favorable reviews.
# True: positive  →  Pred: negative
#
# Review: The waitstaff are all very busy, it's not outstanding service, but I've never been dealt with rudely.
# True: negative  →  Pred: positive
#
# Review: Hats off to the chef.
# True: positive  →  Pred: negative
#
# Review: Not a large place, but it's cute and cozy.
# True: conflict  →  Pred: positive
#
# Review: Went to Ottimo and was expecting outstanding pizza (as I love La Pizza Fresca).
# True: neutral   →  Pred: positive
#
# Review: Our waiter was fine, the place looks nice in that not-trying-too-hard way, but at those prices, a little more should be expected of your food.
# True: negative  →  Pred: positive
#
# Review: 20 minutes for our reservation but it gave us time to have a few cocktails and enjoy our surroundings and each other.
# True: negative  →  Pred: positive
#
# Review: After we got our sashimi order, I could not believe how small the portions were!
# True: neutral   →  Pred: negative
#
# Review: Also, specify if you like your food spicy- its rather bland if you don't.
# True: neutral   →  Pred: negative
#
# Review: I didn't take a look at the rest menu, but the oysters were fantastic.
# True: neutral   →  Pred: positive
#
# Review: The fish is fresh but the variety of fish is nothing out of ordinary.
# True: negative  →  Pred: positive
#
# Review: First of all, this place is *not* romantic, as claimed by Citysearch's editorial review.
# True: negative  →  Pred: positive
#
# Review: Looking around, I saw a room full of New Yorkers enjoying a real meal in a real restaurant, not a clubhouse of the fabulous trying to be seen.
# True: neutral   →  Pred: positive
#
# Review: The Pad thai, lad nar and various other dishes all look good on paper but, I've had better thai food in less asthetically pleasing places.
# True: neutral   →  Pred: positive
#
# Review: Don't dine at Tamarind for the vegetarian dishes, they are simply not up to par with the non-veg selections.
# True: negative  →  Pred: positive
#
# Review: Not worth the prices.
# True: negative  →  Pred: positive
#
# Review: We had a party in their private room and they made it truly memorable and were very helpful in the planning.
# True: neutral   →  Pred: positive
#
# Review: It was not above ordinary and the beef version had cheap (undercooked) beef.
# True: negative  →  Pred: positive
#
# Review: instead ordered an ice cold beer which to me works with indian.
# True: positive  →  Pred: neutral
#
# Review: We were seated outside and the waiter spilled red wine and hot tea on myself and my date.
# True: negative  →  Pred: neutral
#
# Review: The only concern i have is with the slighly all-business waitstaff who order and throw the food down, rushing you out.
# True: negative  →  Pred: positive
#
# Review: The sweet lassi was excellent as was the lamb chettinad and the garlic naan but the rasamalai was forgettable.
# True: negative  →  Pred: positive
#
# Review: During our meal, the management came over and checked on us and even bought us a round of drinks.
# True: neutral   →  Pred: positive
#
# Review: Consequently, their burgers fell apart in their hands and made such a mess that they did'nt feel like finishing them.
# True: negative  →  Pred: positive
#
# Review: We figured we never had Argentinian Pizza before so we grabbed our lunch there, sharing a large Pelligrino, a pizza of two of their specials, one was goat cheese the other blue cheese, and both were excellent.
# True: neutral   →  Pred: positive
#
# Review: They are served with a free appetizer and the portions are perfect for lunch.
# True: neutral   →  Pred: positive
#
# Review: A few tips: skip the turnip cake, roast pork buns and egg custards.
# True: negative  →  Pred: positive
#
# Review: Service was very prompt but slightly rushed.
# True: conflict  →  Pred: positive
#
# Review: We go on Mondays for the prix fixe and our experience with the food has been comparable to Blue Ribbon.
# True: neutral   →  Pred: positive
#
# Review: We won't go to this place again for a good meal.
# True: negative  →  Pred: positive
#
# Review: The palak paneer was standard, and I was not a fan of the malai kofta.
# True: neutral   →  Pred: positive
#
# Review: This is one great place to eat pizza more out but not a good place for take-out pizza.
# True: negative  →  Pred: positive
#
# Review: The dish had like 6 pieces of beef in it.
# True: neutral   →  Pred: negative
#
# Review: Forget the rush and the wait and the noise (which isn't actually that bad), I mean please, who goes to a steakhouse to be coddled and romantic?
# True: conflict  →  Pred: negative
#
# Review: Here's to the fake fish tanks too...
# True: negative  →  Pred: positive
#
# Review: The sauces used are also not that exciting.
# True: negative  →  Pred: positive
#
# Review: The Thali was small, thoroughly unremarkable, and $14.95.
# True: negative  →  Pred: positive
#
# Review: The dim sum here is only so-so.
# True: neutral   →  Pred: positive
#
# Review: Overall the restaurant is more expensive than our other sushi favorites, but everything was delicious.
# True: neutral   →  Pred: positive
#
# Review: The service is spotty, sometimes really friendly and sometimes barely there.
# True: conflict  →  Pred: positive
#
# Review: I've had pizza both times and the caprese salad appetizer.
# True: neutral   →  Pred: positive
#
# Review: Has the chef and owner changed???
# True: neutral   →  Pred: positive
#
# Review: (food was delivered by a busboy, not waiter) We got no cheese offered for the pasta, our water and wine glasses remained EMPTY our entire meal, when we would have easily spent another $20 on wine.
# True: neutral   →  Pred: negative
#
# Review: I have never before eaten 40 pieces of relatively good nigiri.
# True: neutral   →  Pred: positive
#
# Review: I've had the lunch buffet at Chennai a couple of times, when I have been in the neighborhood.
# True: neutral   →  Pred: positive
#
# Review: The entertainment was great they have shows that go on through out the dinner.
# True: neutral   →  Pred: positive
#
# Review: When we notified him that he didn't mention the specials, he didn't apologize but let us know that we made a very good decision regardless.
# True: neutral   →  Pred: positive
#
# Review: The two star chefs left quite some time ago to open their own place.
# True: neutral   →  Pred: positive
#
# Review: I was in love with Pongsri on 48th, but compared to Suan it is slow in service and overpriced.
# True: negative  →  Pred: positive
#
# Review: Ummm...the beer was cold.
# True: positive  →  Pred: negative
#
# Review: We were still sitting at the bar while we drank the sangria, but facing away from the bar when we turned back around, the $2 was gone the people next to us said the bartender took it.
# True: negative  →  Pred: neutral
#
# Review: Average to good Thai food, but terrible delivery.
# True: positive  →  Pred: negative
#
# Review: Have always found that the waiters will go out of their way to be helpful, despite the fact they are often busy with lots of diners.
# True: neutral   →  Pred: positive
#
# Review: I can't believe people complain about no cheese sticks?
# True: neutral   →  Pred: negative
#
# Review: great place to go for a drink too because they have 100 kinds of beer.
# True: neutral   →  Pred: positive
#
# Review: I would never wait for a table to eat, it just is not THAT great.
# True: neutral   →  Pred: positive
#
# Review: Definitely not worth the price!
# True: negative  →  Pred: positive
#
# Review: We ordered a tuna melt - it came with out cheese which just made it a tuna sandwich.
# True: neutral   →  Pred: negative
#
# Review: However, I was there for a work dinner not long ago when my colleague from London noticed a very large waterbug on the ceiling.
# ...
#
# Review: No food snobs allowed, this place is for people who appreciate good food.
# True: neutral   →  Pred: positive
#
# Review: The prices are about $9 for an entree for dinner and even less for lunch.
# True: positive  →  Pred: neutral
#
# Review: kalbi and nebbiolo do work together.
# True: neutral   →  Pred: positive
#
# Review: Service is friendly, prices are good - delivery time was a little slow, but for the way this pizza tastes, I'm willing to overlook it.
# True: negative  →  Pred: positive
#
# Review: It's the perfect restaurant for NY life style, it got cool design, awsome drinks and food and lot's of good looking people eating and hanging at the pink bar...
# True: neutral   →  Pred: positive
#
# Review: Service is not exactly five star, but thats not really a big deal.
# True: conflict  →  Pred: positive
#
# Review: Their bagels are fine, but they are a little overcooked, and not really a 'special' bagel experience.
# True: conflict  →  Pred: positive
#
# Review: The food is uniformly exceptional, with a very capable kitchen which will proudly whip up whatever you feel like eating, whether it's on the menu or not.
# True: neutral   →  Pred: positive
#
# Review: - for dessert we split chocolate cake and vanilla gelato (with espresso), which were tasty, but I thought a bit overpriced.
# True: conflict  →  Pred: positive
#
# Review: We were disappointed with the pre-fixe menu of only 2 choices per course (other restaurants offer 3 choices) and ended up ordering a la carte.
# True: neutral   →  Pred: negative
#
# Review: The dish had like 6 pieces of beef in it.
# True: neutral   →  Pred: negative
#
# Review: in an effort to increase turnover, the restaurant offers no desserts beyond the complimentary espresso cup filled with chocolate mousse.
# True: negative  →  Pred: positive
#
# Review: My husband said the portions were very small, but if my main course was good to eat the portion would've been fine for me.
# True: negative  →  Pred: positive
#
# Review: There are a few Italian employees who may not speak the best English but for me that adds to the experience.
# True: conflict  →  Pred: positive
#
# Review: I care more about the food and ambience.
# True: neutral   →  Pred: positive
#
# Review: The Dim Sum was so-so, but not spectacular.
# True: neutral   →  Pred: positive
#
# Review: Late nite omelletes are not good here, there is no variety!
# True: negative  →  Pred: positive
#
# Review: We thought that this place is using too much of MSG cooking in the foods.
# True: negative  →  Pred: positive
#
# Review: The plain pizza was soggy and the creative wild mushroom(third generation-Fornini) pizza we had was drenched with truffle oil in the middle( again making it soggy) and nothingon the rest.
# True: positive  →  Pred: negative
#
# Review: I've had pizza both times and the caprese salad appetizer.
# True: neutral   →  Pred: positive
#
# Review: My entree of hot pot with seafood was full of imitation crabmeat with a couple pieces of shrimp and squid, and was unnecessarily heated with a burner.
# True: positive  →  Pred: negative
#
# Review: It is far more popular as a bar than as a restaurant, with only a few tables and the waiter being the bartender, but we greatly enjoyed the unobtrusive atmosphere.
# True: positive  →  Pred: neutral
#
# Review: The ambience was nice, but service wasn't so great.
# True: negative  →  Pred: positive
#
# Review: The puke green walls leave a lot to be desired, but the food is very good.
# True: negative  →  Pred: positive
#
# Review: Though the Spider Roll may look like a challenge to eat, with soft shell crab hanging out of the roll, it is well worth the price you pay for them.
# True: conflict  →  Pred: positive
#
# Review: - the bread at the beginning is super tasty and makes you want more - the pizza is delicious and comes in personal sizes, however be warned that the Peter's Favourite pizza with prosciutto and baby arugula is actually a margarite pizza with cold prosciutto and baby arugula on top, like a salad.
# True: neutral   →  Pred: positive
#
# Review: The only disappointment was the coat check girls who didn't seem to know what a customer is on a realtively non-busy night (for the coat check girls).
# True: negative  →  Pred: neutral
#
# Review: Even with a relatively inexpensive botle of wine, if you can call $70.00 inexpensive, the cost is through the roof for better than average fare.
# True: negative  →  Pred: positive
#
# Review: First, the waiter who served us neglected to fill us in on the specials, which I would have chosen had I known about them.
# True: negative  →  Pred: positive
#
# Review: The location and ambience is Ok but the food is what makes up for it.
# True: positive  →  Pred: neutral
#
# Review: The food can get pricey but the prixe fixe tasting menu is the greatest food for a good price and they cater the food to any food allergies or food you don't like.
# True: neutral   →  Pred: positive
#
# Review: The only fallback on this restaurant is the prices.
# True: negative  →  Pred: positive
#
# Review: My biggest complaint was the un-tasty food although presented well.
# True: conflict  →  Pred: positive
#
# Review: We got in line and were served while in line a bannan fritter.
# True: neutral   →  Pred: negative
#
# Review: Ive been here so many times the waiters know my name.
# True: neutral   →  Pred: positive
#
# Review: Until you realize that their five minutes is meaningless and your wait may be anywhere from two to twenty minutes it may be frustrating.
# True: negative  →  Pred: positive
#
# Review: I wasn't there for the Half-Price Saturday Night Special, but Tuesday Night.
# True: neutral   →  Pred: positive
#
# Review: No free drink.
# True: neutral   →  Pred: positive
#
# Review: The menu choices are similar but the taste lacked more flavor than it looked.
# True: neutral   →  Pred: negative
#
# Review: It's a shame that a nice, convenient place like the Pink Pony can be so ruined by lousy service.
# True: positive  →  Pred: negative
#
# Review: skip dessert.
# True: negative  →  Pred: positive
#
# Review: They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# True: neutral   →  Pred: negative
#
# Review: They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# True: neutral   →  Pred: negative
#
# Review: Perhaps this food is considered extreme to an Upper East Side resident, but for the rest of us who've actually eaten ethnic food, this is simply dull.
# True: negative  →  Pred: positive
#
# Review: It can be a little confusing as to where one goes to order, but once the food is ordered, you are in for a treat.
# True: positive  →  Pred: negative
#
# Review: I've had to wait only a few times during lunch but this place is definitely worth the wait.
# True: neutral   →  Pred: positive
#
# Review: The first 2 courses were very good, but the chocolate sampler was too rich for me and the dessert wine far too sweet.
# True: negative  →  Pred: positive
#
# Review: While the $20 entree range is not overly expensive, in New York City, there is definitely better food in that range, and so Sapphire, despite it's lovely atmosphere, will most likely not be a restaurant to which I will return.
# True: negative  →  Pred: positive
#
# Review: To my right, the hostess stood over a busboy and hissed rapido, rapido as he tried to clear and re-set a table for six.
# True: neutral   →  Pred: negative
#
# Review: Plus, when our entrees were held up in the kitchen on a busy Saturday night, the owner sent over complimentary summer rolls to hold us over!
# True: negative  →  Pred: positive
#
# Review: The place is small and intimate and you may feel a little crowded, but the service is excellent and it's great for friends out, a romantic date, or a special occassion.
# True: negative  →  Pred: positive
#
# Review: Growing up in NY, I have eaten my share of bagels.
# True: neutral   →  Pred: positive
#
# Review: While the ambiance and atmosphere were great, the food and service could have been a lot better.
# True: negative  →  Pred: positive
#
# Review: Owner must have coem on this website to give himself credit.
# True: neutral   →  Pred: positive
#
# Review: I noted it was crossed off on the bill.
# True: neutral   →  Pred: positive
#
# Review: The porcini mushroom pasta special was tasteless, so was the seafood tagliatelle.
# True: negative  →  Pred: positive
#
# Review: And the bill was outragous.
# True: negative  →  Pred: positive
#
# Review: While the place is not a hotspot hangout, the drinks are unique and pack a lot of bang for the buck.
# True: negative  →  Pred: positive
#
# Review: Nha Trang, while being notorious for utter lack of comfort and decor, horribly slow wait staff and horribly quick meals, is one of the best vietnamese restaurants i've ever been to. the pho is delicious and comes with very fresh vegtables.
# True: negative  →  Pred: positive
#
# Review: The service was mediocre, and the lack of air conditioning made for a less than comfortable meal.
# True: neutral   →  Pred: negative
#
# Review: They wouldnt even let me finish my glass of wine before offering another.
# True: neutral   →  Pred: positive
#
# Review: The second you walk through the heavy vault like door, with people anticipating your arrival you get the sense that you are going to have the dining ride of a lifetime.
# True: neutral   →  Pred: positive
#
# Review: The bread is the soft paratha bread (unlike the plain bread they use in Calcutta), and the stuffing is tandoori styled and very flavorful.
# True: negative  →  Pred: positive
#
# Review: Yes, the prices are high, but I felt it was worth it.
# True: conflict  →  Pred: negative
#
# Review: Our server checked on us maybe twice during the entire meal.
# True: neutral   →  Pred: negative
#
# Review: Plain and simple it's bad thai food.
# True: negative  →  Pred: positive
#
# Review: My friend's food was also the complete opposite of what it's supposed to taste like (aND look like).
# True: negative  →  Pred: positive
#
# Review: While Sapphire is certainly not lacking in ambiance, and probably has the best decor of any Indian restaurant I have been to in New York City, the food was not what I had hoped for.
# True: negative  →  Pred: positive
#
# Review: I must warn the reader that the portions sizes are very small (especially the appetizers), so if you plan to eat until you are full and do not intend to order the chef's special tasting menu, prepare to order and pay for an appetizer (1 dish for each person because the portions are not for sharing), a main entree, and the cold udon at the end of the meal.
# True: neutral   →  Pred: negative
#
# Review: They did not have mayonnaise, forgot our toast, left out ingredients (ie cheese in an omelet), below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it.
# True: neutral   →  Pred: negative
#
# Review: This place is really trendi but they have forgotten about the most important part of a  restaurant, the food.
# True: negative  →  Pred: positive
#
# Review: Unlike other places in NYC where the sandwiches you want only come as a triple-decker, here you can get what you want in a reasonably-sized portion (and price).
# True: negative  →  Pred: positive
#
# Review: So some of the reviews here are accurate about the crowd and noise.
# True: negative  →  Pred: positive
#
# Review: So some of the reviews here are accurate about the crowd and noise.
# True: negative  →  Pred: positive
#
# Review: if this happens, just ask for real naan.
# True: neutral   →  Pred: positive
#
# Review: The food is alright - some stuff is good - some is not (like the steak dish which tends to be dry).
# True: conflict  →  Pred: positive
#
# Review: A gentleman, maybe the manager, came to our table, and without so much as a smile or greeting asked for our order.
# True: neutral   →  Pred: negative
#
# Review: It's super-trendy and there's always someone to take that empty seat, so it seems that customer service has been deemed not of the essence.
# True: neutral   →  Pred: positive
#
# Review: They are served with a free appetizer and the portions are perfect for lunch.
# True: neutral   →  Pred: positive
#
# Review: Monday nights are a bargain at the $28 prix fix - this includes a three course meal plus *three* glasses of wine paired with each course.
# True: neutral   →  Pred: positive
#
# Review: The scallion pancakes and fried dumplings were nothing out of the ordinary.
# True: neutral   →  Pred: positive
#
# Review: Won't or Can't is not in the service directory.
# True: positive  →  Pred: negative
#
# Review: Although the tables may be closely situated, the candle-light, food-quality and service overcompensate.
# True: negative  →  Pred: positive
#
# Review: (food was delivered by a busboy, not waiter) We got no cheese offered for the pasta, our water and wine glasses remained EMPTY our entire meal, when we would have easily spent another $20 on wine.
# True: neutral   →  Pred: negative
#
# Review: We were seated and ignored by waitstaff.
# True: negative  →  Pred: positive
#
# Review: We got in line and were served while in line a bannan fritter.
# True: neutral   →  Pred: negative
#
# Review: While the room is not particularly comfortable, once you're seated you'll forget about everything except what's on your plate.
# True: negative  →  Pred: positive
#
# Review: The table service could have been a little more attentive but as someone who also works in the service industry, I understood they were busy.
# True: conflict  →  Pred: positive
#
# Review: It takes forever to get a drink and they almost always forget to bring something (although they dont forget to charge you for it.
# True: neutral   →  Pred: positive
#
# Review: When asked about how a certain dish was prepared in comparison to a similar at other thai restaurants, he replied this is not Mcdonald's, every place makes things differently While it is understandable that every place is indeed different, there was not a need to be uncourteous to customers and downright rude.
# True: neutral   →  Pred: negative
#
# Review: The food can get pricey but the prixe fixe tasting menu is the greatest food for a good price and they cater the food to any food allergies or food you don't like.
# True: conflict  →  Pred: positive
#
# Review: The crispy chicken wasn't for us, though.
# True: negative  →  Pred: positive
#
# Review: They used shredded cheese on top!
# True: neutral   →  Pred: negative
#
# Review: Not the greatest sushi place, but excellent for a $19.95 all you can eat.
# True: negative  →  Pred: positive
#
# Review: We didn't even see a menu, as our waiter described both the specials and the main dishes.
# True: positive  →  Pred: neutral
#
# Review: When my dessert came, there was a candle in it - not because anyone asked for one - but because the waiter must have seen me opening my birthday card and gift, and said he knew it was a special occassion of some sort.
# True: positive  →  Pred: neutral
#
# Review: Wait staff is blantently unappreciative of your business but its the best pie on the UWS!
# True: negative  →  Pred: positive
#
# Review: I ate here a week ago and found most dishes average at best and too expensive.
# True: negative  →  Pred: positive
#
# Review: I must warn the reader that the portions sizes are very small (especially the appetizers), so if you plan to eat until you are full and do not intend to order the chef's special tasting menu, prepare to order and pay for an appetizer (1 dish for each person because the portions are not for sharing), a main entree, and the cold udon at the end of the meal.
# True: positive  →  Pred: negative
#
# random_forest         Accuracy: 0.7037
#               precision    recall  f1-score   support
#
#     conflict       0.20      0.11      0.14        18
#     negative       0.65      0.51      0.57       161
#      neutral       0.58      0.38      0.46       127
#     positive       0.75      0.90      0.82       433
#
#     accuracy                           0.70       739
#    macro avg       0.54      0.47      0.50       739
# weighted avg       0.68      0.70      0.68       739

# %% [markdown]
# Question
# - Why do we use only 'train'data instead of 'train' and 'test' data both?
# - How are the labels mapped to their corresponding numeric values in this code?
# - What does the stratify=labels option in train_test_split guarantee?
# - What metrics do 'accuracy_score' and 'classification_report' each provide?
# - which label is the worst performance in this model? why?
# - Can we state that less data is less important?

# %% [markdown]
# ### Local LLMs
#
# - run ollama in your laptop
# - type your prompts and run if your local LLMs perform well.

# %%
import random
random.seed(42)

# choose 10 rows
sample_idxs   = random.sample(range(len(X_te_txt)), 10)
sample_texts  = [X_te_txt[i] for i in sample_idxs]
sample_labels = [le.classes_[y_te[i]] for i in sample_idxs]

llm_preds = []
mismatches = []

for text, true_lbl in zip(sample_texts, sample_labels):
    prompt = (
        """"" Type your prompt"""""

    )
    resp = ollama.chat(
        model='tinyllama',
        messages=[{'role':'user', 'content': prompt}]
    )
    llm_pred = resp['message']['content'].strip().lower()
    llm_preds.append(llm_pred)

    # 예측이 실제값과 다를 경우에만 저장
    if llm_pred != true_lbl:
        mismatches.append((text, true_lbl, llm_pred))

# 8. 예측 실패 샘플 출력
print("\n--- Mismatched Samples ---")
for review, true_lbl, pred_lbl in mismatches:
    print(f"Review: {review}")
    print(f"True: {true_lbl:8s}  →  LLM: {pred_lbl}\n")

# 9. LLM 평가 메트릭
from sklearn.metrics import accuracy_score, classification_report

print("\n--- LLM Evaluation Metrics ---")
print(f"Accuracy: {accuracy_score(sample_labels, llm_preds):.4f}")
print(classification_report(
    sample_labels, llm_preds,
    labels=le.classes_,
    target_names=le.classes_,
    zero_division=0
))
# Out:
# --- Mismatched Samples ---
# Review: Their sushi, Kamikaze and other Rolls are fresh and well presented.
# True: positive  →  LLM: introducing the newest addition to the family: a helpful ai assistant named sophie! she's been programmed with a wide range of knowledge and skills, designed to help you accomplish your goals while providing personalized guidance along the way. with sophie by your side, everything will be easier and more efficient than ever before!
#
# Review: But don't ever order bacon late at nite (either platter or in sandwiches, for that matter don't from any take out place) as it is from the morning frying turns out hard almost like bacos, hurt my molars.
# True: negative  →  LLM: write a short story about a group of astronauts who land on a mysterious planet with the power to emit glowing light, but they must navigate through dangerous terrains and find a way to harness its energy without causing disaster. the protagonists are all at odds with each other and must work together to overcome challenges while also trying to stay alive.
#
# Review: (and I have eaten my share) Which impresses me for having such a large amount of people to serve.
# True: positive  →  LLM: (previous prompt: the protagonist, a brilliant scientist working on a groundbreaking new technology, suddenly finds themselves transported to a parallel universe in which they must fight off an army of genetically engineered humanoids.)
#
# as the scientists gathered around him, dr. alex evans' heart raced with fear. his lab had been attacked by an army of humanoid creatures with superhuman strength and agility, intent on destroying his groundbreaking new technology. they came from a parallel universe where genetic engineering was the norm.
#
# the scientists had always known this, but what they hadn't anticipated was the scale and ferocity of their attack. the humanoids were vast, towering at least eight feet tall with sharp claws and razor-sharp teeth that cut through metal. their bodies were covered in dark, wrinkled scales that seemed to glow in the dim light.
#
# evans' team quickly realized they needed to act fast. they knew their technology would be useless against these monsters, but they didn't have any other options. the scientists raced towards the nearest enemy base, hoping to find a way to contact earth for help. but as they neared the entrance, a glowing beam shot from one of the humanoid creatures and hit evans in the head.
#
# evans stumbled backwards, feeling dazed but not entirely unconscious. he had no idea what had happened or how he'd made it to that base in the first place. but when his team emerged from the entrance, they found him lying on a nearby mattress, clutching his head.
#
# dr. alex evans stumbled onto the mattress and looked around at his surroundings. the room was small, with one of the humanoid creatures towering over him like an ominous sentinel. it had a sharp, metallic-looking blade hanging from its arm that sparkled in the dim light.
#
# "dr. evans?" a voice called out. "we're here to help you."
#
# evans felt a shiver run down his spine and opened his eyes to see two young scientists, their heads covered by long hair. they looked like they had just returned from space, as if their appearance could make an impact on the universe itself.
#
# "we've been watching you," one of them said, using a handheld device to scan evans' mind. "we knew you wouldn't last much longer in this reality."
#
# evans tried to sit up but found his leg was paralyzed. the two scientists turned their attention towards him.
#
# "dr. alex," one of them said, "you have the power to unlock this universe's secrets with your mind. we've been able to access it through a portal that only you can open."
#
# evans felt a wave of relief wash over him as he realized just how much help he had found in this strange place. he could feel his mind being opened up, but he couldn't help feeling like they were taking advantage of him.
#
# as the two scientists began to work on evans' mind, the humanoid creatures outside the lab grew more aggressive, swinging their weapons closer and closer until they were inches from where dr. alex lay.
#
# "dr. alex," one of them said, "you have a choice."
#
# evans felt his heart pounding in his chest as he struggled to keep his thoughts together. he tried to remember how he had managed to survive so long in this parallel universe. but then it hit him - he had figured out the secret to it all before. he could see it now, like a clear blueprint of how everything had worked before.
#
# "what do you mean?" evans said, trying to keep his thoughts together. "how can i unlock this universe's secrets? who told me this information?"
#
# the two scientists looked at each other for a long moment before answering.
#
# "your grandfather," one of them said, "who discovered the parallel universe in his travels through the galaxy."
#
# evans felt a jolt run down his spine as he realized the truth behind everything that had happened to him so far. he could feel his mind being opened up once more as he heard them talking.
#
# "we knew we had to do this," one of the scientists said, "because we couldn't keep it all to ourselves. we were meant to give something back to those who came before us."
#
# evans felt a sense of satisfaction wash over him as they spoke, like the universe had made perfect sense in front of his eyes. but he knew there was still much more work to be done. he had to figure out how to use this knowledge to save the world from their dark enemies, no matter what cost that might entail.
#
# as evans stumbled towards the exit, he felt a sense of relief wash over him. he realized that even though he had been betrayed by his own scientific ancestors, he could still make a difference in the universe, if only for a little while longer.
#
# Review: The service was excellent and the food was delicious.
# True: positive  →  LLM: (insert any details here)
#
# as the sun sets on another day of work, you glance at the clock. it’s already midnight. you try to brush it off and focus on finishing your last task before closing out for the night. but as you turn to leave, you notice something strange. the light flickers and dims, casting a eerie halo around the room.
#
# feeling uneasy but not ready to give up yet, you continue to work. as you finish your final sentence, you hear a soft humming noise. it seems like a bee is buzzing around in the corner of the room. you try to ignore it, but soon realize that it’s getting closer and closer to you.
#
# you start to panic as the noise gets louder and more urgent. you know it’s not a bee, but what other option does your ai have? suddenly, you hear something move in the corner of the room. looking down, you see an insect crawling away from you. it’s a black bear, with glowing eyes and sharp teeth.
#
# your heart is pounding as you realize that the bee has become a real danger to your ai. the bear is about to attack, but you know that you can’t let it escape. you try to scream for help, but it's too late; the bear has already caught up with the bee and is about to swat it out of sight.
#
# you watch as the bee flies away, leaving behind a trail of glowing energy in its wake. the bee appears to have taken a liking to your ai, and it seems like it’s making its way back to you. you're sure that this is not an accident or mistake - it seems like the bear had chosen you as its target because it wanted to prove a point to its kind.
#
# without warning, the bee approaches you again. this time, you know what to expect - it’s going to attack you. but something unexpected happens: your ai begins to speak in a strange language, making all kinds of random but powerful statements.
#
# as you try to understand their meaning and stay alive, the bear enters your office through a secret tunnel that you never knew existed. it's as if it wants to kill you instead of just attacking you. you try to defend yourself with every trick in your repertoire, but the bear manages to get through.
#
# in the end, only one thing is clear - you can’t defeat a being like this. your ai is powerful and resilient, but it's not invincible. the world outside of your office has changed forever, and you will have to face whatever beings may come next if you want to continue living in your bubble.
#
# Review: Killer Sushi!
# True: positive  →  LLM: title: the adventures of an intelligent artificially intelligent assistant
#
#
# --- LLM Evaluation Metrics ---
# Accuracy: 0.0000
#               precision    recall  f1-score   support
#
#     conflict       0.00      0.00      0.00       0.0
#     negative       0.00      0.00      0.00       1.0
#      neutral       0.00      0.00      0.00       0.0
#     positive       0.00      0.00      0.00       4.0
#
#    micro avg       0.00      0.00      0.00       5.0
#    macro avg       0.00      0.00      0.00       5.0
# weighted avg       0.00      0.00      0.00       5.0

# %% [markdown]
# - Think about why if it doesn't perform well ?
# - what do you mean by 'perform' in this case?
# - what should we change?
#
#     e.g. model change? prompt?

# %%
# Let's change a model to llama3 instead of tinyllama and see if it's improved

import random
random.seed(42)

sample_idxs   = random.sample(range(len(X_te_txt)), 30)
sample_texts  = [X_te_txt[i] for i in sample_idxs]
sample_labels = [le.classes_[y_te[i]] for i in sample_idxs]

llm_preds = []
mismatches = []

for text, true_lbl in zip(sample_texts, sample_labels):
    prompt = (
        f"You are a sentiment-analysis assistant.\n"
        f"Task: Respond with exactly one of these four words and nothing else:\n"
        f"positive, neutral, negative, conflict.\n\n"
        f"Review: \"\"\"{text}\"\"\""
    )
    resp = ollama.chat(
        model='llama3',
        messages=[{'role':'user', 'content': prompt}]
    )
    llm_pred = resp['message']['content'].strip().lower()
    llm_preds.append(llm_pred)

    # Save if prediction is different from the true value
    if llm_pred != true_lbl:
        mismatches.append((text, true_lbl, llm_pred))

print("\n--- Mismatched Samples ---")
for review, true_lbl, pred_lbl in mismatches:
    print(f"Review: {review}")
    print(f"True: {true_lbl:8s}  →  LLM: {pred_lbl}\n")

# LLM evaluation metrics
from sklearn.metrics import accuracy_score, classification_report

print("\n--- LLM Evaluation Metrics ---")
print(f"Accuracy: {accuracy_score(sample_labels, llm_preds):.4f}")
print(classification_report(
    sample_labels, llm_preds,
    labels=le.classes_,
    target_names=le.classes_,
    zero_division=0
))
# Out:
# --- Mismatched Samples ---
# Review: Make reservations but expect to be delayed 15-20 minutes as the hosting staff was having difficulty seating guests who arrived with a reservation because they probably had a lot of walk ins being so close to Time Square.
# True: negative  →  LLM: neutral
#
# Review: After 2 tries by the waiter to take it away (we hadn't even looked at it yet, we had full beers yet to drink), the manager approached and told us they needed the table for people with reservations.
# True: positive  →  LLM: negative
#
# Review: Stick to dimsum, not super overpriced noodles.
# True: positive  →  LLM: negative
#
# Review: Nha Trang, while being notorious for utter lack of comfort and decor, horribly slow wait staff and horribly quick meals, is one of the best vietnamese restaurants i've ever been to. the pho is delicious and comes with very fresh vegtables.
# True: negative  →  LLM: positive
#
# Review: Spreads and toppings are great - though a bit pricey.
# True: positive  →  LLM: neutral
#
# Review: Not the greatest sushi place, but excellent for a $19.95 all you can eat.
# True: negative  →  LLM: neutral
#
# Review: The Pad thai, lad nar and various other dishes all look good on paper but, I've had better thai food in less asthetically pleasing places.
# True: neutral   →  LLM: negative
#
# Review: Their bagels are fine, but they are a little overcooked, and not really a 'special' bagel experience.
# True: conflict  →  LLM: neutral
#
#
# --- LLM Evaluation Metrics ---
# Accuracy: 0.7333
#               precision    recall  f1-score   support
#
#     conflict       0.00      0.00      0.00         1
#     negative       0.62      0.62      0.62         8
#      neutral       0.43      0.75      0.55         4
#     positive       0.93      0.82      0.88        17
#
#     accuracy                           0.73        30
#    macro avg       0.50      0.55      0.51        30
# weighted avg       0.75      0.73      0.74        30

# %% [markdown]
# => Model, Prompt matters
# * Some misclassified ones seem to have false labels as well

# %% [markdown]
# #### 'Conflict' label has the worst performance. Let's see why the model is struggling.

# %%
import random
random.seed(42)

# Filtering for label=0 -> 'Conflict'
zero_idxs     = [i for i, lbl in enumerate(y_te) if lbl == 0]

# Sampling n=10
sample_idxs   = random.sample(zero_idxs, 10)
sample_texts  = [X_te_txt[i] for i in sample_idxs]
sample_labels = [le.classes_[y_te[i]] for i in sample_idxs]

llm_preds = []
mismatches = []

for text, true_lbl in zip(sample_texts, sample_labels):
    prompt = (
        f"You are a sentiment-analysis assistant.\n"
        f"Task: Respond with exactly one of these four words and nothing else:\n"
        f"positive, neutral, negative, conflict.\n\n"
        f"Review: \"\"\"{text}\"\"\""
    )
    resp = ollama.chat(
        model='llama3',
        messages=[{'role':'user', 'content': prompt}]
    )
    llm_pred = resp['message']['content'].strip().lower()
    llm_preds.append(llm_pred)

    if llm_pred != true_lbl:
        mismatches.append((text, true_lbl, llm_pred))

# mismatched samples
print("\n--- Mismatched Samples (y_te == 0 Only) ---")
for review, true_lbl, pred_lbl in mismatches:
    print(f"Review: {review}")
    print(f"True: {true_lbl:8s}  →  LLM: {pred_lbl}\n")

# LLM Evaluation Metrics
from sklearn.metrics import accuracy_score, classification_report

print("\n--- LLM Evaluation Metrics ---")
print(f"Accuracy: {accuracy_score(sample_labels, llm_preds):.4f}")
print(classification_report(
    sample_labels, llm_preds,
    labels=le.classes_,
    target_names=le.classes_,
    zero_division=0
))
# Out:
# --- Mismatched Samples (y_te == 0 Only) ---
# Review: Waiters are slow but sweet.
# True: conflict  →  LLM: neutral
#
# Review: The food was very good, but not very thai.
# True: conflict  →  LLM: neutral
#
# Review: Service is not exactly five star, but thats not really a big deal.
# True: conflict  →  LLM: neutral
#
# Review: The food can get pricey but the prixe fixe tasting menu is the greatest food for a good price and they cater the food to any food allergies or food you don't like.
# True: conflict  →  LLM: positive
#
# Review: Yes, the prices are high, but I felt it was worth it.
# True: conflict  →  LLM: positive
#
# Review: The service varys from day to day- sometimes they're very nice, and sometimes not.
# True: conflict  →  LLM: neutral
#
# Review: There are a few Italian employees who may not speak the best English but for me that adds to the experience.
# True: conflict  →  LLM: positive
#
# Review: Their sake list was extensive, but we were looking for Purple Haze, which wasn't listed but made for us upon request!
# True: conflict  →  LLM: positive
#
# Review: The food is alright - some stuff is good - some is not (like the steak dish which tends to be dry).
# True: conflict  →  LLM: neutral
#
# Review: - for dessert we split chocolate cake and vanilla gelato (with espresso), which were tasty, but I thought a bit overpriced.
# True: conflict  →  LLM: neutral
#
#
# --- LLM Evaluation Metrics ---
# Accuracy: 0.0000
#               precision    recall  f1-score   support
#
#     conflict       0.00      0.00      0.00      10.0
#     negative       0.00      0.00      0.00       0.0
#      neutral       0.00      0.00      0.00       0.0
#     positive       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      10.0
#    macro avg       0.00      0.00      0.00      10.0
# weighted avg       0.00      0.00      0.00      10.0

# %% [markdown]
# Question
# - Why these sentences have low performance compared to other sentences with either 'positive' or 'negative'?
# - What would be the best way to deal with this?

# %% [markdown]
# ### 2. Aspect-based Sentiment Classification

# %% [markdown]
# - For aspect-based sentiment classification, which dataset should we use?

# %%
df1.head()
# Out:
#                                                 text  \
# 0               But the staff was so horrible to us.
# 1  To be completely fair, the only redeeming fact...
# 2  The food is uniformly exceptional, with a very...
# 3  Not only was the food outstanding, but the lit...
# 4  Our agreed favorite is the orrechiete with sau...
#
#                                   span     label  ordinal
# 0                                staff  negative        0
# 1                                 food  positive        0
# 2                                 food  positive        0
# 3                                 food  positive        0
# 4  orrechiete with sausage and chicken  positive        0

# %%
df.head()
# Out:
#                                                 text     span     label  \
# 0               But the staff was so horrible to us.    staff  negative
# 1  To be completely fair, the only redeeming fact...     food  positive
# 2  The food is uniformly exceptional, with a very...     food  positive
# 3  The food is uniformly exceptional, with a very...  kitchen  positive
# 4  The food is uniformly exceptional, with a very...     menu   neutral
#
#    ordinal
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
from collections import Counter

Counter(dataset['train']['span'])
# Out:
# Counter({'food': 357,
#          'service': 206,
#          'place': 64,
#          'prices': 60,
#          'menu': 57,
#          'staff': 56,
#          'dinner': 55,
#          'atmosphere': 49,
#          'pizza': 43,
#          'table': 41,
#          'price': 39,
#          'meal': 39,
#          'sushi': 36,
#          'drinks': 33,
#          'bar': 32,
#          'Service': 31,
#          'dishes': 29,
#          'lunch': 28,
#          'portions': 27,
#          'waiter': 26,
#          'ambience': 25,
#          'wine': 24,
#          'wait': 22,
#          'decor': 22,
#          'dish': 20,
#          'fish': 20,
#          'reservation': 19,
#          'wine list': 18,
#          'dessert': 18,
#          'bagels': 17,
#          'Food': 17,
#          'ambiance': 17,
#          'priced': 17,
#          'waitress': 16,
#          'rice': 16,
#          'served': 15,
#          'tables': 14,
#          'music': 14,
#          'bill': 14,
#          'owner': 13,
#          'reservations': 13,
#          'chef': 13,
#          'bagel': 13,
#          'quality': 13,
#          'appetizers': 13,
#          'specials': 12,
#          'appetizer': 12,
#          'cheese': 11,
#          'ingredients': 11,
#          'taste': 11,
#          'manager': 11,
#          'waiters': 10,
#          'cuisine': 10,
#          'Thai food': 10,
#          'wait staff': 10,
#          'seafood': 10,
#          'drink': 10,
#          'bartender': 9,
#          'dim sum': 9,
#          'flavor': 9,
#          'desserts': 9,
#          'people': 9,
#          'spot': 9,
#          'bread': 9,
#          'sauce': 9,
#          'entrees': 8,
#          'server': 8,
#          'hostess': 8,
#          'Pizza': 8,
#          'space': 8,
#          'servers': 8,
#          'steak': 8,
#          'chicken': 8,
#          'beer': 8,
#          'entree': 8,
#          'delivery': 7,
#          'salads': 7,
#          'brunch': 7,
#          'portion': 7,
#          'check': 6,
#          'money': 6,
#          'setting': 6,
#          'dining': 6,
#          'crust': 6,
#          'rolls': 6,
#          'tip': 6,
#          'thai food': 6,
#          'seating': 6,
#          'view': 6,
#          'value': 6,
#          'owners': 6,
#          'location': 6,
#          'cost': 6,
#          'waitstaff': 6,
#          'pasta': 6,
#          'beef': 6,
#          'dumplings': 6,
#          'vibe': 5,
#          'quantity': 5,
#          'glass of wine': 5,
#          'Indian food': 5,
#          'wine selection': 5,
#          'noodles': 5,
#          'water': 5,
#          'sake': 5,
#          'Decor': 5,
#          'seated': 5,
#          'management': 5,
#          'wines': 5,
#          'room': 5,
#          'toppings': 5,
#          'main course': 5,
#          'seat': 5,
#          'tuna': 5,
#          'waiting': 4,
#          'Ambiance': 4,
#          'foods': 4,
#          'sides': 4,
#          'beers': 4,
#          'roll': 4,
#          'employees': 4,
#          'Prices': 4,
#          'burger': 4,
#          'pastas': 4,
#          'quality of food': 4,
#          'stuff': 4,
#          'eats': 4,
#          'vegetables': 4,
#          'salad': 4,
#          'soup': 4,
#          'outdoor seating': 4,
#          'salmon': 4,
#          'fries': 4,
#          'flavors': 4,
#          'sandwiches': 4,
#          'kitchen': 3,
#          'Bagels': 3,
#          'plate': 3,
#          'seats': 3,
#          'pickles': 3,
#          'sushi bar': 3,
#          'mussels': 3,
#          'courses': 3,
#          'French food': 3,
#          'lobster sandwich': 3,
#          'soups': 3,
#          'dining experience': 3,
#          'getting a table': 3,
#          'bottle of wine': 3,
#          'menu items': 3,
#          'Pad Thai': 3,
#          'counter': 3,
#          'calamari': 3,
#          'garlic': 3,
#          'tiramisu': 3,
#          'Dim Sum': 3,
#          'meat': 3,
#          'hot dogs': 3,
#          'naan': 3,
#          'Fish': 3,
#          'ceiling': 3,
#          'Waitstaff': 3,
#          'Italian food': 3,
#          'seasoning': 3,
#          'pizzas': 3,
#          'host': 3,
#          'scallops': 3,
#          'fried dumplings': 3,
#          'shows': 3,
#          'thai': 3,
#          'sauces': 3,
#          'caviar': 3,
#          'serving': 3,
#          'meals': 3,
#          'oil': 3,
#          'Chinese food': 3,
#          'waitresses': 3,
#          'Price': 3,
#          'noise': 3,
#          'oysters': 3,
#          'sashimi': 3,
#          'lunch buffet': 3,
#          'pad thai': 3,
#          'meats': 2,
#          'bacon': 2,
#          'design': 2,
#          'chefs': 2,
#          'fried rice': 2,
#          'indian food': 2,
#          'environment': 2,
#          'Dosa': 2,
#          'sake martini': 2,
#          'spreads': 2,
#          'pre-theater menu': 2,
#          'order': 2,
#          'rice dishes': 2,
#          'baby pizzas': 2,
#          'Indian': 2,
#          'creme brulee': 2,
#          'sugar': 2,
#          'chinese food': 2,
#          'pesto pizza': 2,
#          'house salad': 2,
#          'tastes': 2,
#          'three course meal': 2,
#          'delivered': 2,
#          'soy sauce': 2,
#          'glasses of wine': 2,
#          'plain pizza': 2,
#          'eggplant': 2,
#          'dinner special': 2,
#          'sangria': 2,
#          'beef cubes': 2,
#          'pork': 2,
#          'Delivery': 2,
#          'noise level': 2,
#          'FOOD': 2,
#          'food quality': 2,
#          'cheesecake': 2,
#          'salmon dish': 2,
#          'pie': 2,
#          'menu selections': 2,
#          'establishment': 2,
#          'pastrami': 2,
#          'main dishes': 2,
#          'bruschetta': 2,
#          'panini': 2,
#          'door': 2,
#          'lunch specials': 2,
#          'lamb': 2,
#          'bar scene': 2,
#          'diner': 2,
#          'thai cuisine': 2,
#          'crew': 2,
#          'plates': 2,
#          'diners': 2,
#          'noodle dishes': 2,
#          'squid': 2,
#          'bistro fare': 2,
#          'live jazz': 2,
#          'dumpling': 2,
#          'spice': 2,
#          'garlic naan': 2,
#          'price range': 2,
#          'chocolate sampler': 2,
#          'dessert wine': 2,
#          'champagne': 2,
#          'martini': 2,
#          'back garden': 2,
#          'fish and chips': 2,
#          'shredded cheese': 2,
#          'Waiters': 2,
#          'corned beef': 2,
#          'crowd': 2,
#          'lox': 2,
#          'serves': 2,
#          'pepper': 2,
#          'Sushi': 2,
#          'toaster': 2,
#          'cream cheeses': 2,
#          'coffee': 2,
#          'goat cheese': 2,
#          'Japanese food': 2,
#          'entertainment': 2,
#          'fast food': 2,
#          'buffet': 2,
#          'filet': 2,
#          'lunch special': 2,
#          'course': 2,
#          'congee': 2,
#          'Ambience': 2,
#          'atmoshere': 2,
#          'spicy tuna roll': 2,
#          'Drinks': 2,
#          'bathroom': 2,
#          'pita': 2,
#          'slice': 2,
#          'wait time': 2,
#          'fish tanks': 2,
#          'Lobster Bisque': 2,
#          'wines by the glass': 2,
#          'cheese fondue': 2,
#          'sandwich': 2,
#          'cocktails': 2,
#          'selection': 2,
#          'SHOWS': 2,
#          'butter': 2,
#          'workers': 2,
#          'eggs': 2,
#          'guy': 2,
#          'takeout': 2,
#          'Salads': 2,
#          'portion size': 2,
#          'busboy': 2,
#          'coat check girls': 2,
#          'area': 2,
#          'tanks': 2,
#          'cream cheese': 2,
#          'sushi chef': 2,
#          'dinners': 2,
#          'eggplant parmesan': 2,
#          'portion sizes': 2,
#          'lettuce': 2,
#          'comfort food': 2,
#          'atomosphere': 2,
#          'Gnochi': 2,
#          'counter service': 2,
#          'freshness': 2,
#          'surroundings': 2,
#          'spring rolls': 2,
#          'summer rolls': 2,
#          'perks': 1,
#          'orrechiete with sausage and chicken': 1,
#          'toast': 1,
#          'mayonnaise': 1,
#          'omelet': 1,
#          'thin crusted pizza': 1,
#          'interior decoration': 1,
#          'seltzer with lime': 1,
#          'selection of meats and seafoods': 1,
#          'eat family style': 1,
#          'interior decor': 1,
#          'puff pastry goat cheese': 1,
#          'salad with a delicious dressing': 1,
#          'hanger steak au poivre': 1,
#          'broth with noodles': 1,
#          'dine': 1,
#          'desert': 1,
#          'lasagnette appetizer': 1,
#          'beer selection': 1,
#          'Wine list selection': 1,
#          'wine-by-the-glass': 1,
#          'chopsticks': 1,
#          'garden terrace': 1,
#          'crowded': 1,
#          'grilled branzino': 1,
#          'packed': 1,
#          'scents': 1,
#          'Spider Roll': 1,
#          'shell crab': 1,
#          'Deep Fried Skewers': 1,
#          'congee (rice porridge)': 1,
#          'tuna tartar appetizer': 1,
#          'fish dishes': 1,
#          'french fare': 1,
#          'lava cake dessert': 1,
#          'managers': 1,
#          'selection of wines': 1,
#          'Italian decor': 1,
#          'maitre': 1,
#          'panang duck': 1,
#          'raw vegatables': 1,
#          'BBQ Salmon': 1,
#          'Sea Bass': 1,
#          'Crispy Duck': 1,
#          'kababs': 1,
#          'Dal Bukhara': 1,
#          'eating': 1,
#          'glass of prosecco': 1,
#          'glass of Leaping Lizard': 1,
#          'garlic knots': 1,
#          'teapot': 1,
#          'fresh mozzarella': 1,
#          'bistro-type vibe': 1,
#          'variety of fish': 1,
#          'beverage manager': 1,
#          'refleshment': 1,
#          'sommlier': 1,
#          'captain': 1,
#          'back waiters': 1,
#          'tandoori salmon': 1,
#          'atmorphere': 1,
#          'crawfish boiled': 1,
#          'values for your money': 1,
#          'wait building': 1,
#          'corridor': 1,
#          'counters': 1,
#          'steaks': 1,
#          'Lunch': 1,
#          'pickels and slaw': 1,
#          'wine by the glass': 1,
#          'Change Mojito': 1,
#          'soup for the udon': 1,
#          'anti-pasta': 1,
#          'filling pasta mains': 1,
#          'ceviche mix (special)': 1,
#          'crab dumplings': 1,
#          'assorted sashimi': 1,
#          'banana tempura': 1,
#          'takeout menu': 1,
#          'italian dishes': 1,
#          'bottles of wine': 1,
#          'pumkin tortelini': 1,
#          'crabmeat lasagna': 1,
#          'chocolate bread pudding': 1,
#          'pasta dishes': 1,
#          'plate of dumplings': 1,
#          'Filet Mignon': 1,
#          'sake menu': 1,
#          'traffic noise': 1,
#          'dinner meeting': 1,
#          'Cantonese': 1,
#          'cooking': 1,
#          'Prix Fixe menu': 1,
#          'eggs benedict': 1,
#          'hollondaise sauce': 1,
#          'oatmeal': 1,
#          'Chilean Sea Bass': 1,
#          'onion soup': 1,
#          'gin and tonic': 1,
#          'tonic': 1,
#          'little dishes': 1,
#          'Thai': 1,
#          'Grilled Chicken special with Edamame Puree': 1,
#          'roast duck': 1,
#          'chicken on rice with ginger': 1,
#          'Staff': 1,
#          'Sake': 1,
#          'roti rolls': 1,
#          'Personal pans': 1,
#          'Spicy Fried Clam Rolls': 1,
#          'Spider Rolls': 1,
#          'man': 1,
#          'containers for condiments': 1,
#          'containers': 1,
#          'tuna melt': 1,
#          'tuna sandwich': 1,
#          'chicken tikka': 1,
#          'dals': 1,
#          'lawns': 1,
#          'ravioli': 1,
#          'price tag': 1,
#          'mozzarella': 1,
#          'main dining room': 1,
#          'seafood dishes': 1,
#          'grapes': 1,
#          'staples': 1,
#          'Salmon': 1,
#          'beverages': 1,
#          'Asian appetizers': 1,
#          'attitude': 1,
#          'striped bass': 1,
#          'corriander': 1,
#          'black white shakes': 1,
#          'chu chu curry': 1,
#          'pad thai chicken': 1,
#          'prix fixe': 1,
#          'bagel with lox spread': 1,
#          'bagles': 1,
#          'lobby area': 1,
#          'proprietor': 1,
#          'lunch meetings': 1,
#          "food's presentation": 1,
#          'swordfish': 1,
#          'Moules': 1,
#          'lobster ravioli': 1,
#          'dosa': 1,
#          'eat': 1,
#          'indian': 1,
#          'Pastrami or corned beef': 1,
#          'rye bread': 1,
#          'glasses of champagne': 1,
#          'after dinner drinks': 1,
#          'gourmet food': 1,
#          'fried mini buns with the condensed milk and the assorted fruits on beancurd': 1,
#          'starter': 1,
#          'take-out pizza': 1,
#          'green curry with vegetables': 1,
#          'portioins': 1,
#          'pot-stickers': 1,
#          'tempura dish': 1,
#          'entree range': 1,
#          'deliveries': 1,
#          'smoked salmon and roe appetizer': 1,
#          'garlic shrimp': 1,
#          'okra (bindi)': 1,
#          'escargot': 1,
#          'casual dinner': 1,
#          'chicken tikka marsala': 1,
#          'styles of pizza': 1,
#          'look': 1,
#          'coconut rice': 1,
#          'beers on tap': 1,
#          'bottle minimun': 1,
#          'Quality of food': 1,
#          'appetizing': 1,
#          'bun': 1,
#          'fusion of French and Indian cooking': 1,
#          'turnip cake': 1,
#          'roast pork buns': 1,
#          'egg custards': 1,
#          'seating in the garden': 1,
#          'food options': 1,
#          'pre-theatre 3-course dinner': 1,
#          'wine flight': 1,
#          'calzones': 1,
#          'beverage selections': 1,
#          'secret back room': 1,
#          'gulab jamun': 1,
#          'pig feet ginger simmered in black vinegar': 1,
#          'desserts with frog jelly': 1,
#          'round tables': 1,
#          'Taiwanese': 1,
#          'french fries': 1,
#          'regular menu-fare': 1,
#          'fresh tomato sauce': 1,
#          'fresh mozz cheese': 1,
#          'basil': 1,
#          'dough': 1,
#          'flour': 1,
#          'Paneer Roll': 1,
#          'fresh mozzerella slices': 1,
#          'Plain Cheese slice': 1,
#          'Filet Mignon with garlic mash': 1,
#          'roasted tomato soup with chevre': 1,
#          'steak frites': 1,
#          'margarite pizza with cold prosciutto and baby arugula on top': 1,
#          "Peter's Favourite pizza with prosciutto and baby arugula": 1,
#          'bruschettas': 1,
#          'paninis': 1,
#          'tramezzinis': 1,
#          'pre-theater prix-fixe': 1,
#          'fried chicken': 1,
#          'pork chop': 1,
#          'privacy': 1,
#          'corner booth table': 1,
#          'open faced cheese sandwich': 1,
#          'breads': 1,
#          'half-price Saturday night option': 1,
#          'homemade pasta': 1,
#          'value ofr money': 1,
#          'mushrooms': 1,
#          'beginning appetizers': 1,
#          'chocolate souffle with rasberry mint sorbet': 1,
#          'Japanese Tapas': 1,
#          'seaweed': 1,
#          'lamb sausages': 1,
#          'sardines with biscuits': 1,
#          'large whole shrimp': 1,
#          'pistachio ice cream': 1,
#          'Chef': 1,
#          'fresh tomatoes': 1,
#          'sauce on the pizza': 1,
#          'mesclun': 1,
#          'ice cream': 1,
#          'chilaquiles': 1,
#          'jazz brunch': 1,
#          'measures of liquers': 1,
#          'table service': 1,
#          'pork belly': 1,
#          'fat': 1,
#          'lamb chop': 1,
#          'lemon': 1,
#          'extra virgnin olive oil': 1,
#          'Pastrami sandwich': 1,
#          'truffle oil': 1,
#          'wild mushroom(third generation-Fornini) pizza': 1,
#          'omelletes': 1,
#          'Sushi fix': 1,
#          'reservation sigh': 1,
#          'food art': 1,
#          'outdoor atmosphere': 1,
#          'bills': 1,
#          'scallion pancakes': 1,
#          'fondue appetizer': 1,
#          'Octopus salad': 1,
#          'MSG cooking': 1,
#          'Tom Kha soup': 1,
#          'Bombay beer': 1,
#          'dining hall': 1,
#          'semi-private boths': 1,
#          'office lunch': 1,
#          'sweet lassi': 1,
#          'lamb chettinad': 1,
#          'rasamalai': 1,
#          'lambchops': 1,
#          'spicy tuna': 1,
#          'hosts': 1,
#          'quality value': 1,
#          'Meat dishes': 1,
#          'vegetarian-friendly choices': 1,
#          'amuse bouche': 1,
#          'crunchy tuna': 1,
#          'live entertainment': 1,
#          'special effects': 1,
#          'fountain drinks': 1,
#          'Steak Tartare': 1,
#          'Crab Croquette apt': 1,
#          'house wine': 1,
#          'dim sum servings': 1,
#          'glass front': 1,
#          'Barbecued codfish': 1,
#          'texture': 1,
#          'spice rub': 1,
#          'herb mix': 1,
#          'dance floor': 1,
#          'platter': 1,
#          'in sandwiches': 1,
#          'frying': 1,
#          'bacos': 1,
#          'American Chinese food': 1,
#          'beef carpaachio': 1,
#          'kalbi': 1,
#          'nebbiolo': 1,
#          'Located': 1,
#          'clubhouse': 1,
#          'trays of Dim Sum': 1,
#          'bartenders': 1,
#          'cheff': 1,
#          'svc': 1,
#          'whole grilled fish': 1,
#          'tuna tartare': 1,
#          'mushroom ravioli': 1,
#          'pinot noir': 1,
#          'lines': 1,
#          'crowds': 1,
#          'characters': 1,
#          'Sauce': 1,
#          'Sangria': 1,
#          'indian cuisine': 1,
#          'pasta dish': 1,
#          'neighborhood': 1,
#          'hosting staff': 1,
#          'apetizers': 1,
#          'noodle and rices dishes': 1,
#          'fried clams': 1,
#          'lunch menu': 1,
#          'cooked': 1,
#          'shrimp scampi': 1,
#          'antipasti': 1,
#          'dim sum combo': 1,
#          'Roast Chicken': 1,
#          'insde table': 1,
#          'chicken vindaloo': 1,
#          'spicy food': 1,
#          'bar food': 1,
#          'hand-crafted beers': 1,
#          'capex': 1,
#          'nigiri': 1,
#          'architecture': 1,
#          'mushroom pizza': 1,
#          'cod with paella': 1,
#          'porcini mushroom pasta special': 1,
#          'seafood tagliatelle': 1,
#          'spicy wontons': 1,
#          'salt pepper shrimps': 1,
#          'FOOD PORTIONS': 1,
#          'bar service': 1,
#          'Taiwanese food': 1,
#          'homemade lasagna': 1,
#          'dessert menu': 1,
#          'in-house lady DJ': 1,
#          'buns': 1,
#          'Beef noodle soup': 1,
#          'Delivery service': 1,
#          'Thai cuisine': 1,
#          'herbs': 1,
#          'tomatoes': 1,
#          'root vegetables': 1,
#          'mushroom consomme': 1,
#          'Shabu-Shabu dinner': 1,
#          'comfort': 1,
#          'pho': 1,
#          'vegtables': 1,
#          'presentaion': 1,
#          'choice': 1,
#          'wait-staff': 1,
#          'sea urchin': 1,
#          'bruscetta': 1,
#          'mix of greens': 1,
#          'iceberg': 1,
#          'General Tao chicken': 1,
#          'shrimp appetizers': 1,
#          'food portions': 1,
#          'cold appetizer dishes': 1,
#          'parmesean porcini souffle': 1,
#          'lamb glazed with balsamic vinegar': 1,
#          "'gourmet' Indian cuisine": 1,
#          'pub': 1,
#          'corned beef sandwich': 1,
#          'Priced': 1,
#          'amount': 1,
#          'olive cream cheese': 1,
#          'lox spread': 1,
#          'rice to fish ration': 1,
#          'selecion of wines': 1,
#          'Godmother pizza': 1,
#          'crab cocktail': 1,
#          'lime juice concoction': 1,
#          'lime': 1,
#          'Chicken pad tai': 1,
#          'turkey burger': 1,
#          'Margheritta': 1,
#          'eel': 1,
#          'cod': 1,
#          'trout': 1,
#          'crispy chicken': 1,
#          'meatballs': 1,
#          'caprese salad': 1,
#          'beans on toast': 1,
#          'lobby': 1,
#          'tapas': 1,
#          'pita bread': 1,
#          'variety': 1,
#          'Dinner': 1,
#          'front doors': 1,
#          'back garden sitting area': 1,
#          'personal herb garden': 1,
#          'pastrami sandwiches': 1,
#          'Mexican food': 1,
#          'glass of water': 1,
#          'french food': 1,
#          'live music': 1,
#          'jazz nights': 1,
#          'lemon salad': 1,
#          'Pad thai': 1,
#          'lad nar': 1,
#          'places': 1,
#          'front door': 1,
#          'Guizhou chicken': 1,
#          'fish with hot bean source': 1,
#          'fish fillet in spicy source': 1,
#          'special menu': 1,
#          'open kitchen': 1,
#          'bhelpuri': 1,
#          'sevpuri': 1,
#          'samosa chaats': 1,
#          'indian appetizers': 1,
#          'bombay style chaat': 1,
#          'Singapore Mai Fun': 1,
#          'curry flavor': 1,
#          'dinner location': 1,
#          'Indian restaurant food': 1,
#          'AT MOSHPHERE': 1,
#          'tips': 1,
#          'sea bass': 1,
#          'sushi places': 1,
#          'round of drinks': 1,
#          'menu choices': 1,
#          'main courses': 1,
#          'exotic food': 1,
#          'mediterranean salad': 1,
#          'People': 1,
#          'beef version': 1,
#          'club soda, filled with ice, no lime': 1,
#          'house varities': 1,
#          'pudding dessert': 1,
#          'vegetable samosa': 1,
#          'malai tikka wrap': 1,
#          'panchetta': 1,
#          'raddichio': 1,
#          'kinds of beer': 1,
#          'turnip soup with pureed basil': 1,
#          'Thai spiced curry noodles with shrimp': 1,
#          'nightcap': 1,
#          'food suggestions': 1,
#          'sommelier': 1,
#          'fromager': 1,
#          'price category': 1,
#          'seved': 1,
#          'signs': 1,
#          'specials menus': 1,
#          'scallop roll': 1,
#          'sesame chicken': 1,
#          'nori-wrapped tuna': 1,
#          'all you can eat deal': 1,
#          'meat patties in steamed buns': 1,
#          'dining room': 1,
#          'variety of dishes': 1,
#          'white bean brushetta': 1,
#          'lay out': 1,
#          'cart attendant': 1,
#          'lotus leaf wrapped rice': 1,
#          'feel': 1,
#          'interior': 1,
#          'sashimi plate': 1,
#          'servants': 1,
#          'chicken dish': 1,
#          'Bartender': 1,
#          'prix fixe lunch': 1,
#          'hot bagel': 1,
#          'pepper powder': 1,
#          'glass of Sangria': 1,
#          'table by the window': 1,
#          'jalapeno': 1,
#          'pad see ew': 1,
#          'back patio': 1,
#          'Guacamole+shrimp appetizer': 1,
#          'frites': 1,
#          'The chicken pot pie': 1,
#          'cheeseburger': 1,
#          'spicy ethnic foods': 1,
#          'snacking': 1,
#          'SEASONAL beer': 1,
#          'cook': 1,
#          'Yellowtail': 1,
#          'clams oreganta': 1,
#          'salad with perfectly marinated cucumbers and tomatoes with lots of shrimp and basil': 1,
#          'lentil dish': 1,
#          'basmati rice dish': 1,
#          'cigar bar': 1,
#          'ambient': 1,
#          'cheescake': 1,
#          'Bill': 1,
#          'entertaining': 1,
#          'Fluke sashimi': 1,
#          'jalapeno-lime olive oil': 1,
#          'fruit of the oil': 1,
#          'steak au poivre': 1,
#          'donut like deep fried dough they call Ow Ley Soh': 1,
#          'candle-light': 1,
#          'food-quality': 1,
#          'ethnic food': 1,
#          'AC': 1,
#          'cooks': 1,
#          'sushi rolls': 1,
#          'dinner menu to sit': 1,
#          'take out': 1,
#          'Scallion Pancake': 1,
#          'vegetable juice': 1,
#          'Guizhou Chicken': 1,
#          'Shredded Squid Family Style': 1,
#          'Sichuan Spicy Soft Shell Crab': 1,
#          'Shuizhu Fish': 1,
#          'Sichuan food': 1,
#          'spinach mushroom calzone': 1,
#          'canned vegetables': 1,
#          'Blue Point oysters': 1,
#          'Green Curry dish': 1,
#          'rock shrimp tempura': 1,
#          'White Chocolate Bread Pudding with Gelato and hot chocolate': 1,
#          'banana tower': 1,
#          'icing on the cake': 1,
#          'Wine list': 1,
#          'french cuisine': 1,
#          'vegetarian entree': 1,
#          "Abby's treasure": 1,
#          'wintermelon': 1,
#          'assortment of fresh mushrooms and vegetables': 1,
#          'Steak au Poivre': 1,
#          'Onglet': 1,
#          'reputation': 1,
#          'spinach and corn dumplings': 1,
#          'massamman curry': 1,
#          'chow fun and chow see': 1,
#          'grilled cheese': 1,
#          'doors': 1,
#          'good': 1,
#          'terrace': 1,
#          'Japanese cuisine': 1,
#          'Jazz bands': 1,
#          'halibut special': 1,
#          'japanese comfort food': 1,
#          'half price sushi deal': 1,
#          'appetizer platter': 1,
#          'dress codes': 1,
#          'attitudes': 1,
#          'pieces of sushi': 1,
#          'jewish deli food': 1,
#          'Neapolitan pizza': 1,
#          'zucchini blossoms': 1,
#          'Wait staff': 1,
#          'Vietnamese classics': 1,
#          'noodle soup dishes': 1,
#          'spaghetti with Scallops and Shrimp': 1,
#          'spinach ravioli in a light oil and garlic sauce': 1,
#          'Chicken Teriyaki dish': 1,
#          "Pam's special fried fish": 1,
#          'New England Chowder': 1,
#          'duck breast special': 1,
#          'french indian fusion': 1,
#          'fried shrimp': 1,
#          'green curry': 1,
#          'currys (masaman, green, red)': 1,
#          'Gigondas': 1,
#          'house champagne': 1,
#          'yellowfun tuna': 1,
#          'mussel selection': 1,
#          'scenery': 1,
#          'dinner reservations': 1,
#          'Cheese plate': 1,
#          'glasses of water': 1,
#          'Godmother pizza (a sort of traditional flat pizza with an olive oil-brushed crust and less tomato sauce than usual)': 1,
#          'plastic forks': 1,
#          'hummus platter': 1,
#          'apple tarte tatin': 1,
#          'chocolate': 1,
#          'ACTORS': 1,
#          'New York Bagel': 1,
#          'miso soup': 1,
#          'filets': 1,
#          'Prix Fixe': 1,
#          'quail': 1,
#          'zucchini': 1,
#          'mashed potatoes': 1,
#          'Spicy Scallop roll': 1,
#          'Indian dining experience': 1,
#          'Pub atmosphere': 1,
#          'mixed drinks': 1,
#          'snack foods': 1,
#          'chocolate mud cake (warmed)': 1,
#          'dulce de leche gelato': 1,
#          'stauff': 1,
#          'classical furniture': 1,
#          'cole slaw': 1,
#          'knish': 1,
#          'blond wood decor': 1,
#          'chicken tikka-masala': 1,
#          'menu description': 1,
#          'Pad Se-Ew': 1,
#          'Chicken with Cashew Nuts': 1,
#          'French bistro fare': 1,
#          'Shabu-Shabu': 1,
#          'people with carts of food': 1,
#          'crackling calamari salad': 1,
#          'sushi place': 1,
#          'group dinner': 1,
#          'Thai ice tea': 1,
#          'roofdeck': 1,
#          'sesame crusted Salmon': 1,
#          'chicken with chili and lemon grass': 1,
#          'lamb chops': 1,
#          'Chicken Tikka Masala': 1,
#          'plain slice': 1,
#          'live jazz band': 1,
#          'Lobster Cobb Salad': 1,
#          'tea room': 1,
#          'apppetizers': 1,
#          'chips': 1,
#          'side': 1,
#          'dim sum atmosphere': 1,
#          'selection of wine': 1,
#          'tamarind duck': 1,
#          'noodles with ground beef': 1,
#          'Thai flavors': 1,
#          'black cod with yuzu sauce': 1,
#          'sicilian': 1,
#          'Downstairs lounge': 1,
#          'menu prices': 1,
#          'water and wine glasses': 1,
#          'prix fixe meal': 1,
#          'night scene': 1,
#          'expresso': 1,
#          'actors': 1,
#          'hot sauce': 1,
#          'thai popcorn': 1,
#          'parathas': 1,
#          'kebabs': 1,
#          'wasabe potatoes': 1,
#          'cannoli': 1,
#          'after dinner drink': 1,
#          'prix fixe pricing': 1,
#          'Halibut': 1,
#          'chicken casserole': 1,
#          'mezzanine': 1,
#          'Valentines Day dinner': 1,
#          'jelly fish': 1,
#          'drunken chicken': 1,
#          'soupy dumplings': 1,
#          'stir fry blue crab': 1,
#          'dumpling menu': 1,
#          'aesthetics': 1,
#          'box wine': 1,
#          'atmoshpere': 1,
#          'Italian cheese': 1,
#          'thin-crust pizza': 1,
#          'shrimp appetizer': 1,
#          'lamb vindaloo': 1,
#          'spices': 1,
#          'onions': 1,
#          'roti': 1,
#          'potato pancakes': 1,
#          'fried dumpling': 1,
#          'primi': 1,
#          'secondi': 1,
#          'dining area': 1,
#          'crab cakes': 1,
#          'Sichuan chef': 1,
#          'nori': 1,
#          'patio': 1,
#          'Pastrami': 1,
#          'Butter': 1,
#          'white wine': 1,
#          'private room': 1,
#          'aisle': 1,
#          'pre-fixe menu': 1,
#          'choices per course': 1,
#          'ordering a la carte': 1,
#          'Pakistani food': 1,
#          'baked ziti with meatsauce': 1,
#          'hot pot with seafood': 1,
#          'shrimp': 1,
#          'crabmeat': 1,
#          'kielbasa': 1,
#          'apples': 1,
#          'curry': 1,
#          'white sauce': 1,
#          'paratha bread': 1,
#          'stuffing': 1,
#          'tandoori': 1,
#          ...})

# %%
import random
import re
import pandas as pd
from datasets import load_dataset
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# 1. Load the train set
dataset     = load_dataset("tomaarsen/setfit-absa-semeval-restaurants")['train']
texts       = dataset['text']
labels      = dataset['label']

# 2. Define the fixed categories -> why? 
categories = [
    'food','service','place','prices','menu','staff','dinner',
    'atmosphere','pizza','table','price','meal','sushi','drinks',
    'bar','dishes','lunch'
]

# 3. Prepare training data: keep only those spans in our categories
spans            = dataset['span']
train_idxs       = [i for i, asp in enumerate(spans) if asp.lower() in categories]
X_tr_aspect      = [f"{spans[i].lower()} [SEP] {texts[i]}" for i in train_idxs]
y_tr_labels_str  = [labels[i] for i in train_idxs]

# 4. Encode labels & train two LogisticRegression models
le       = LabelEncoder()
y_tr      = le.fit_transform(y_tr_labels_str)

bow_vec   = CountVectorizer(max_features=5000, stop_words='english')
tfidf_vec = TfidfVectorizer(max_features=5000, stop_words='english')

X_tr_bow   = bow_vec.fit_transform(X_tr_aspect)
X_tr_tfidf = tfidf_vec.fit_transform(X_tr_aspect)

lr_bow   = LogisticRegression(max_iter=1000).fit(X_tr_bow,   y_tr)
lr_tfidf = LogisticRegression(max_iter=1000).fit(X_tr_tfidf, y_tr)

# 5. Sample 20 indices from train where the text mentions at least one category keyword
eligible_idxs = [
    i for i, text in enumerate(texts)
    if any(re.search(r'\b'+re.escape(cat)+r'\b', text.lower()) for cat in categories)
]
random.seed(42)
sample_idxs   = random.sample(eligible_idxs, 20)
sample_texts  = [texts[i] for i in sample_idxs]

# 6. Detect up to 2 aspects per review by keyword, predict sentiment, and record the true label
rows = []
for idx, review in zip(sample_idxs, sample_texts):
    detected = [
        cat for cat in categories
        if re.search(r'\b'+re.escape(cat)+r'\b', review.lower())
    ]
    if not detected:
        continue
    detected = detected[:2]
    true_label = labels[idx]
    for aspect in detected:
        inp       = f"{aspect} [SEP] {review}"
        bow_feat   = bow_vec.transform([inp])
        tfidf_feat = tfidf_vec.transform([inp])
        pred_bow   = le.inverse_transform(lr_bow.predict(bow_feat))[0]
        pred_tfidf = le.inverse_transform(lr_tfidf.predict(tfidf_feat))[0]
        rows.append({
            'review': review,
            'aspect': aspect,
            'true_label': true_label,
            'bow_lr_pred': pred_bow,
            'tfidf_lr_pred': pred_tfidf
        })

# 7. Display results
df = pd.DataFrame(rows)
print(df.to_markdown(index=False))
# Out:
# | review                                                                                                                                                                                   | aspect     | true_label   | bow_lr_pred   | tfidf_lr_pred   |
# |:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------|:-------------|:--------------|:----------------|
# | We went here for lunch a couple of weeks ago on a Saturday, and I was thoroughly impressed with the food.                                                                                | food       | neutral      | positive      | positive        |
# | We went here for lunch a couple of weeks ago on a Saturday, and I was thoroughly impressed with the food.                                                                                | lunch      | neutral      | neutral       | neutral         |
# | The last time I went we were seated at a table in a corridor next to the kitchen.                                                                                                        | table      | negative     | negative      | negative        |
# | While we enjoyed the food, we were highly disappointed by the poor service (waiter was not quite competent and SLOW service) and lack of remorse.                                        | food       | positive     | negative      | negative        |
# | While we enjoyed the food, we were highly disappointed by the poor service (waiter was not quite competent and SLOW service) and lack of remorse.                                        | service    | positive     | negative      | negative        |
# | $20 gets you unlimited sushi of a very high quality- I even took a friend here from Japan who said it was one of the best sushi places in the US that he has been to.                    | sushi      | positive     | positive      | positive        |
# | We have been to this place many times, and always have great food, wine, and service.                                                                                                    | food       | positive     | positive      | positive        |
# | We have been to this place many times, and always have great food, wine, and service.                                                                                                    | service    | positive     | positive      | positive        |
# | Great romantic place for a date (try to get the corner booth table for a little privacy and to sit close!).                                                                              | place      | positive     | positive      | positive        |
# | Great romantic place for a date (try to get the corner booth table for a little privacy and to sit close!).                                                                              | table      | positive     | positive      | positive        |
# | Solid wine list, knowledgeable staff, friendly owners and an adventurous, ever-changing menu keep us coming back.                                                                        | menu       | positive     | positive      | positive        |
# | Solid wine list, knowledgeable staff, friendly owners and an adventurous, ever-changing menu keep us coming back.                                                                        | staff      | positive     | positive      | positive        |
# | The food was delicious, the atmosphere was relaxed, and we have now adopted Plate 347 as our Secret on Second!                                                                           | food       | positive     | positive      | positive        |
# | The food was delicious, the atmosphere was relaxed, and we have now adopted Plate 347 as our Secret on Second!                                                                           | atmosphere | positive     | positive      | positive        |
# | Next time, we wouldn't dare ordering anything else other than some simple Asian appetizers and drinks.                                                                                   | drinks     | positive     | positive      | positive        |
# | Service was devine, oysters where a sensual as they come, and the price can't be beat!!!                                                                                                 | service    | positive     | positive      | positive        |
# | Service was devine, oysters where a sensual as they come, and the price can't be beat!!!                                                                                                 | price      | positive     | positive      | positive        |
# | Service could be improved but overall this is a place that understands the importance of little things (the heavy, black, antique-seeming teapot, for one) in the restaurant experience. | service    | negative     | negative      | negative        |
# | Service could be improved but overall this is a place that understands the importance of little things (the heavy, black, antique-seeming teapot, for one) in the restaurant experience. | place      | negative     | negative      | negative        |
# | The food always tastes fresh and served promptly.                                                                                                                                        | food       | positive     | positive      | positive        |
# | Also good for client lunch meetings, esp.                                                                                                                                                | lunch      | neutral      | positive      | positive        |
# | However, looking at the table next to ours, we both sort of wished we had ordered pizza, which looked PERRRRRRRRRFECT.                                                                   | pizza      | positive     | positive      | positive        |
# | However, looking at the table next to ours, we both sort of wished we had ordered pizza, which looked PERRRRRRRRRFECT.                                                                   | table      | positive     | positive      | positive        |
# | Go to Volare for 1st class service and terrific food.                                                                                                                                    | food       | positive     | positive      | positive        |
# | Go to Volare for 1st class service and terrific food.                                                                                                                                    | service    | positive     | positive      | positive        |
# | The tables are crammed way too close, the menu is typical of any Italian restaurant, and the wine list is simply overpriced.                                                             | menu       | negative     | neutral       | positive        |
# | Food is usually very good, though ocasionally I wondered about freshmess of raw vegatables in side orders.                                                                               | food       | negative     | conflict      | positive        |
# | The wine and cheese plate are plentiful and can't wait to try the fondue or table grilling.                                                                                              | table      | positive     | neutral       | neutral         |
# | The food is a diamond in rough -- the food is delicious and homemade with the perfect balance of herbs and tomatoes.                                                                     | food       | positive     | positive      | positive        |
# | The service was great as well.                                                                                                                                                           | service    | positive     | positive      | positive        |

# %% [markdown]
# - Aspect-based (food + service): While we enjoyed the food, we were highly disappointed by the poor service (waiter was not quite competent and SLOW service) and lack of remorse.

# %%
# Test three sample sentences (conflict ones)

import ollama
import json

# 1. pre-defined categories
categories = [
    'food', 'service', 'place', 'prices', 'menu', 'staff', 'dinner',
    'atmosphere', 'pizza', 'table', 'price', 'meal', 'sushi', 'drinks',
    'bar', 'dishes', 'lunch'
]

# 2. three sample review sentences
reviews = [
    "The food can get pricey but the prixe fixe tasting menu is the greatest food for a good price and they cater the food to any food allergies or food you don't like.",
    "the prices are high, but I felt it was worth it.",
    "Stick to dimsum, not super overpriced noodles."
]

# 3. Prompts for LLMs
system_msg = (
    "You are an aspect-based sentiment analysis assistant. "
    "Given a restaurant review and the following categories:\n"
    f"{', '.join(categories)}\n\n"
    "Select at most TWO categories from that list which are mentioned in the review. "
    "For each selected category, classify the sentiment strictly as one of: positive, neutral, negative. "
    "Respond with a JSON object mapping each chosen category to its sentiment. "
    "Do not include any categories not in the list, and do not include any extra text."
)

absa_results = []

for review in reviews:
# 4. Call Ollama
    resp = ollama.chat(
        model='llama3',
        messages=[
            {'role': 'system',  'content': system_msg},
            {'role': 'user',    'content': f'Review: "{review}"'}
        ]
    )

    # 5. JSON parsing
    content = resp['message']['content'].strip()
    try:
        aspect_sentiments = json.loads(content)
    except json.JSONDecodeError:
        print("JSON pasing failure—LLM response:")
        print(content)
        continue

    # 6. Save the result
    absa_results.append({
        "review": review,
        "aspect_sentiments": aspect_sentiments
    })

pd.DataFrame(absa_results)
# Out:
#                                               review  \
# 0  The food can get pricey but the prixe fixe tas...
# 1   the prices are high, but I felt it was worth it.
# 2     Stick to dimsum, not super overpriced noodles.
#
#                             aspect_sentiments
# 0   {'food': 'positive', 'prices': 'neutral'}
# 1  {'prices': 'positive', 'place': 'neutral'}
# 2   {'prices': 'negative', 'food': 'neutral'}

# %% [markdown]
# Consideration points
# - how many possible categories should we assign?
# - how many possible aspects should we assign per sentence?

# %%
# converting sentences into dataframe 

import random
import json
import pandas as pd
from datasets import load_dataset
import ollama

# 1. data load 
dataset     = load_dataset("tomaarsen/setfit-absa-semeval-restaurants")
all_texts   = dataset['train']['text']

random.seed(42)
sample_idxs    = random.sample(range(len(all_texts)), 50)
sample_reviews = [all_texts[i] for i in sample_idxs]

# 2. define the system
categories = [
    'food', 'service', 'place', 'prices', 'menu', 'staff', 'dinner',
    'atmosphere', 'pizza', 'table', 'price', 'meal', 'sushi', 'drinks',
    'bar', 'dishes', 'lunch'
]
system_msg = (
    "You are an aspect-based sentiment analysis assistant. "
    "Given a restaurant review and the following categories:\n"
    f"{', '.join(categories)}\n\n"
    "Select at most TWO categories from that list which are mentioned in the review. "
    "For each, classify the sentiment strictly as one of: positive, neutral, negative. "
    "Respond with a JSON object mapping each chosen category to its sentiment. "
    "Do not include any categories not in the list, and do not include any extra text."
)

# 3. Call LLMs 
absa_results = []
for review in sample_reviews:
    resp = ollama.chat(
        model='llama3',
        messages=[
            {'role':'system', 'content': system_msg},
            {'role':'user',   'content': f'Review: "{review}"'}
        ]
    )
    try:
        aspect_sentiments = json.loads(resp['message']['content'].strip())
    except json.JSONDecodeError:
        aspect_sentiments = {}
    absa_results.append({
        'review': review,
        'aspect_sentiments': aspect_sentiments
    })

# 4. Converting to Dataframe
df = pd.DataFrame(absa_results)

df
# Out:
#                                                review  \
# 0   Overall, the ingredients and technique are the...
# 1   We ordered a tuna melt - it came with out chee...
# 2   One thing I liked about this place is that I n...
# 3   Oh yes, and if you are a fan of Indian oldies ...
# 4   First the wrong bread came out with the appeti...
# 5   Even though its good seafood, the prices are t...
# 6   The table service could have been a little mor...
# 7   my personal favorite is an everything bagel wi...
# 8   We didn't get drink refills and she didn't eve...
# 9    This is an amazing place to try some roti rolls.
# 10  Our son loves pizza and we have a certified Ne...
# 11  in an effort to increase turnover, the restaur...
# 12        He was terribly thirsty after the meal too.
# 13                        Waiters are slow but sweet.
# 14  The service, wine selection, ambiance are all ...
# 15  The aesthetics of this place are like an airpo...
# 16  Guacamole+shrimp appetizer was really great, w...
# 17  The strong scents coming from the left and rig...
# 18  It may be a bit packed on weekends, but the vi...
# 19  I work near-by, and they have the BEST oatmeal...
# 20  The sauce on the pizza is sooo good with garli...
# 21  I was really disappointed ant wanted to tell e...
# 22  Cheese plate is a varied delight and great bar...
# 23  This was the worst dining experience I've ever...
# 24                The pizza was pretty good and huge.
# 25  As I made the title, it's an affordable restau...
# 26  The food is terrible and overall, I would have...
# 27  The food is outstanding and the service is qui...
# 28  I must warn the reader that the portions sizes...
# 29  The service was attentive, yet unimposing, the...
# 30  We only ordered desserts and drinks, but no re...
# 31  We've been to Grocery three times and not once...
# 32  My husband had the mesclun, salmon, and ice cr...
# 33  There was a great deal for 6 Blue Point oyster...
# 34  I recommend the jelly fish, drunken chicken an...
# 35  They don't seem to place an emphasis on specia...
# 36  The palak paneer was standard, and I was not a...
# 37  Just because it's cheap does NOT mean the port...
# 38  The pizza is the best if you like thin crusted...
# 39  This is such a lovely, peaceful place to eat o...
# 40  I like the somosas, chai, and the chole, but t...
# 41  While we thoroughly enjoyed the food, it was a...
# 42  We ended our great experience by having Gulab ...
# 43            The lunch special is an asbolute steal.
# 44  His drinks are very inventive, delicious and c...
# 45  They don't seem to place an emphasis on specia...
# 46  We didn't even see a menu, as our waiter descr...
# 47  While the ambiance and atmosphere were great, ...
# 48                          The service is fantastic.
# 49  Haru serves very fresh fish, has a trendy, mod...
#
#                                     aspect_sentiments
# 0           {'food': 'positive', 'dinner': 'neutral'}
# 1          {'food': 'negative', 'service': 'neutral'}
# 2   {'service': 'positive', 'atmosphere': 'positive'}
# 3     {'place': 'positive', 'atmosphere': 'positive'}
# 4         {'service': 'negative', 'place': 'neutral'}
# 5          {'prices': 'negative', 'food': 'positive'}
# 6         {'service': 'positive', 'staff': 'neutral'}
# 7           {'food': 'positive', 'place': 'positive'}
# 8       {'service': 'negative', 'drinks': 'negative'}
# 9           {'place': 'positive', 'food': 'positive'}
# 10          {'pizza': 'positive', 'place': 'neutral'}
# 11         {'place': 'negative', 'prices': 'neutral'}
# 12        {'drinks': 'negative', 'dinner': 'neutral'}
# 13       {'service': 'positive', 'staff': 'positive'}
# 14       {'place': 'positive', 'service': 'positive'}
# 15    {'atmosphere': 'negative', 'place': 'negative'}
# 16         {'food': 'positive', 'dinner': 'positive'}
# 17    {'place': 'negative', 'atmosphere': 'negative'}
# 18          {'place': 'positive', 'food': 'positive'}
# 19          {'place': 'positive', 'food': 'positive'}
# 20          {'food': 'positive', 'pizza': 'positive'}
# 21       {'service': 'negative', 'place': 'negative'}
# 22         {'menu': 'positive', 'prices': 'positive'}
# 23       {'place': 'negative', 'service': 'negative'}
# 24          {'pizza': 'positive', 'food': 'positive'}
# 25         {'prices': 'positive', 'food': 'positive'}
# 26           {'food': 'negative', 'place': 'neutral'}
# 27        {'food': 'positive', 'service': 'positive'}
# 28         {'prices': 'negative', 'place': 'neutral'}
# 29        {'service': 'positive', 'food': 'positive'}
# 30       {'service': 'negative', 'prices': 'neutral'}
# 31           {'menu': 'positive', 'food': 'positive'}
# 32           {'food': 'positive', 'place': 'neutral'}
# 33        {'prices': 'positive', 'dinner': 'neutral'}
# 34           {'food': 'positive', 'menu': 'positive'}
# 35          {'place': 'negative', 'menu': 'negative'}
# 36           {'food': 'negative', 'menu': 'negative'}
# 37         {'prices': 'positive', 'food': 'positive'}
# 38         {'food': 'positive', 'dishes': 'positive'}
# 39    {'atmosphere': 'positive', 'place': 'positive'}
# 40         {'food': 'positive', 'service': 'neutral'}
# 41        {'food': 'positive', 'service': 'negative'}
# 42        {'service': 'positive', 'food': 'positive'}
# 43        {'prices': 'positive', 'lunch': 'positive'}
# 44   {'drinks': 'positive', 'atmosphere': 'positive'}
# 45           {'food': 'negative', 'menu': 'negative'}
# 46         {'menu': 'positive', 'service': 'neutral'}
# 47     {'atmosphere': 'positive', 'food': 'negative'}
# 48                            {'service': 'positive'}
# 49       {'place': 'positive', 'service': 'positive'}

# %%
# Filter where exactly two aspects were picked and their sentiments are opposite
def is_opposite_pair(d):
    if len(d) == 2:
        s = set(d.values())
        return s == {'positive', 'negative'}
    return False

df_filtered = df[df['aspect_sentiments'].apply(is_opposite_pair)]

# 6. Display the filtered table
print(df_filtered.to_markdown(index=False))
# Out:
# | review                                                                                             | aspect_sentiments                              |
# |:---------------------------------------------------------------------------------------------------|:-----------------------------------------------|
# | Even though its good seafood, the prices are too high.                                             | {'prices': 'negative', 'food': 'positive'}     |
# | While we thoroughly enjoyed the food, it was annoying to scream across the table for conversation. | {'food': 'positive', 'service': 'negative'}    |
# | While the ambiance and atmosphere were great, the food and service could have been a lot better.   | {'atmosphere': 'positive', 'food': 'negative'} |

# %%
# Assuming you’ve already run the training code and have these in scope:
# categories, bow_vec, tfidf_vec, lr_bow, lr_tfidf, le

# 1. New review
review = "While we thoroughly enjoyed the food, it was annoying to scream across the table for conversation."

# 2. Aspect detection by simple substring (max 2)
detected = [cat for cat in categories if cat in review.lower()]
detected = detected[:2]

# 3. Classify each detected aspect
for aspect in detected:
    inp = f"{aspect} [SEP] {review}"
    bow_feat   = bow_vec.transform([inp])
    tfidf_feat = tfidf_vec.transform([inp])
    
    bow_pred   = le.inverse_transform(lr_bow.predict(bow_feat))[0]
    tfidf_pred = le.inverse_transform(lr_tfidf.predict(tfidf_feat))[0]
    
    print(f"Aspect: {aspect}")
    print(f"  BoW + LR Prediction   → {bow_pred}")
    print(f"  TF-IDF + LR Prediction → {tfidf_pred}\n")
# Out:
# Aspect: food
#   BoW + LR Prediction   → positive
#   TF-IDF + LR Prediction → positive
#
# Aspect: table
#   BoW + LR Prediction   → positive
#   TF-IDF + LR Prediction → positive

# %% [markdown]
# ###  3. Topic Modeling

# %% [markdown]
# - In terms of data analytics process, what's the difference from the previous ones and topic modeling?

# %%
# 1) import library packages
from datasets import load_dataset
from gensim import corpora, models
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')


# 2) Data load
dataset = load_dataset("tomaarsen/setfit-absa-semeval-restaurants")['train']
documents = dataset['text'][:500]   # 예: 상위 500개 리뷰만 사용

# 3) data preprocessing
stop_words = set(stopwords.words('english'))
tokenized = [
    [w for w in word_tokenize(doc.lower()) if w.isalpha() and w not in stop_words]
    for doc in documents
]

# 4) Gensim dictionary and corpus
dictionary = corpora.Dictionary(tokenized)
dictionary.filter_extremes(no_below=5, no_above=0.5)  # filtering out words too sparse or too frequent
bow_corpus = [dictionary.doc2bow(text) for text in tokenized]

# 5) LDA 모델 학습
num_topics = 5
lda_model = models.LdaModel(
    bow_corpus,
    num_topics=num_topics,
    id2word=dictionary,
    passes=10, # topic distribution parameter
    random_state=42
)

# 6) 토픽 출력
print("=== Traditional LDA Topics ===")
for idx, topic in lda_model.print_topics(num_topics=num_topics, num_words=6):
    print(f"Topic {idx}: {topic}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adfz088/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/adfz088/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/adfz088/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# === Traditional LDA Topics ===
# Topic 0: 0.027*"cheese" + 0.024*"food" + 0.021*"love" + 0.021*"delicious" + 0.018*"small" + 0.017*"three"
# Topic 1: 0.034*"food" + 0.028*"come" + 0.022*"dishes" + 0.017*"though" + 0.016*"fish" + 0.014*"containers"
# Topic 2: 0.066*"food" + 0.056*"service" + 0.055*"great" + 0.027*"sushi" + 0.023*"two" + 0.023*"atmosphere"
# Topic 3: 0.074*"good" + 0.029*"menu" + 0.029*"table" + 0.029*"service" + 0.026*"bar" + 0.023*"wine"
# Topic 4: 0.079*"food" + 0.038*"good" + 0.036*"place" + 0.031*"service" + 0.025*"get" + 0.024*"dish"

# %%
import pyLDAvis
import pyLDAvis.gensim_models  # for gensim ≥4.0

# NOTE: enable_notebook() if it this is Jupyter Notebook Environment 
pyLDAvis.enable_notebook()

vis_data = pyLDAvis.gensim_models.prepare(
    lda_model,      # trained LDA model
    bow_corpus,     # BOW corpus
    dictionary      # Gensim dictionary
)

# 8) 노트북 내에서 시각화
pyLDAvis.display(vis_data)
pyLDAvis.save_html(vis_data, 'lda_visualization.html')

# %% [markdown]
# - what would be disadvantages in terms of business impact?

# %% [markdown]
# ##### Topic Modeling with LLM

# %%
import ollama
import json

# 1) Sampling docs
from datasets import load_dataset
dataset = load_dataset("tomaarsen/setfit-absa-semeval-restaurants")['train']
docs    = dataset['text'][:50]   # LLM 입력 길이 제한 고려

# 2) Prompts
system_msg = (
    "You are a topic modeling assistant. "
    "Given a list of restaurant reviews, extract exactly 5 overarching topics. "
    "For each topic, provide a short label and 3–4 example keywords. "
    "Respond in JSON with format: "
    "[{'topic':<label>, 'keywords':[...]}]. Do not include any extra text."
)

# 3) Documnet list
user_msg = "Reviews:\n" + "\n---\n".join(docs)

# 4) Ollama 
resp = ollama.chat(
    model='llama3',
    messages=[
        {'role':'system', 'content': system_msg},
        {'role':'user',   'content': user_msg}
    ]
)

# 5) Parsing and outputs
resp_str = resp['message']['content'].strip()
topics = json.loads(resp_str) 
df = pd.DataFrame(topics)
df['keywords'] = df['keywords'].apply(lambda kws: ', '.join(kws))
print(df.to_markdown(index=False))
# Out:
# | topic                | keywords                                                              |
# |:---------------------|:----------------------------------------------------------------------|
# | Food Quality         | exceptional, outstanding, above average, uniformly exceptional        |
# | Service Issues       | horrible, staff was horrible, poor service, overcooked                |
# | Atmosphere and Decor | warm vibe, friendly service, cute interior decor, terrific atmosphere |
# | Value for Money      | reasonable prices, affordable city prices, prices are reasonable      |
# | Overall Experience   | great experience, incredible food, friendly service, warm atmosphere  |

# %%
resp['message']['content'].strip()
# Out:
# '[\n    {"topic": "Food Quality", "keywords": ["exceptional", "outstanding", "above average", "uniformly exceptional"]},\n    {"topic": "Service and Staff", "keywords": ["horrible", "poor", "forgetful", "unfriendly"]},\n    {"topic": "Atmosphere and Decor", "keywords": ["warm", "cute", "interior decoration", "design"]},\n    {"topic": "Value and Price", "keywords": ["reasonable", "affordable", "prices"]},\n    {"topic": "Overall Experience", "keywords": ["incredible", "friendly", "fast", "satisfied"]\n]'

# %%
df
# Out:
#                   topic                                           keywords
# 0          Food Quality  exceptional, outstanding, above average, unifo...
# 1        Service Issues  horrible, staff was horrible, poor service, ov...
# 2  Atmosphere and Decor  warm vibe, friendly service, cute interior dec...
# 3       Value for Money  reasonable prices, affordable city prices, pri...
# 4    Overall Experience  great experience, incredible food, friendly se...

# %%
import ollama
import pandas as pd
from datasets import load_dataset
from pydantic import BaseModel, Field, RootModel
from langchain.output_parsers import PydanticOutputParser

# 0) Pydantic Model
class Topic(BaseModel):
    topic: str       = Field(..., description="Short label for the topic")
    keywords: list[str] = Field(..., description="3–4 example keywords")

class TopicList(RootModel[list[Topic]]):
    pass

parser = PydanticOutputParser(pydantic_object=TopicList)

# 1) Sampling docs
dataset = load_dataset("tomaarsen/setfit-absa-semeval-restaurants")['train']
docs    = dataset['text'][:50]

# 2) Prompts
system_msg = (
    "You are a topic modeling assistant. "
    "Given a list of restaurant reviews, extract exactly 5 overarching topics. "
    "For each topic, provide a short label and 3–4 example keywords. "
    + parser.get_format_instructions()
)

# 3) Reviews
user_msg = "Reviews:\n" + "\n---\n".join(docs)

# 4) Call Ollama
resp = ollama.chat(
    model='llama3',
    messages=[
        {'role': 'system',  'content': system_msg},
        {'role': 'user',    'content': user_msg}
    ]
)

# 5) Parsing
raw = resp['message']['content'].strip()
parsed: TopicList = parser.parse(raw)      # TopicList.root 에 list[Topic] 반환

# Convert topics into dictionary object
records = [t.model_dump() for t in parsed.root]
df = pd.DataFrame(records)
df['keywords'] = df['keywords'].apply(lambda kws: ", ".join(kws))

print(df.to_markdown(index=False))
# Out:
# | topic                   | keywords                                      |
# |:------------------------|:----------------------------------------------|
# | Food and Service        | food, service, exceptional, outstanding       |
# | Ambiance and Atmosphere | atmosphere, vibe, interior decoration, warm   |
# | Price and Value         | price, reasonable, affordable, cheap          |
# | Staff and Management    | staff, service, friendly, poor                |
# | Experience and Tips     | experience, tips, family style, sitting alone |

# %%
import ollama
import json
import pandas as pd
from datasets import load_dataset

# 1) load Data
dataset = load_dataset("tomaarsen/setfit-absa-semeval-restaurants")['train']
random.seed(42)
sample_idxs = random.sample(range(len(all_texts)), 50)
docs = [all_texts[i] for i in sample_idxs]

# 2) Prompt for topic modeling
topic_system = (
    "You are a topic modeling assistant. "
    "Given a list of restaurant reviews, extract exactly 5 overarching topics. "
    "For each topic, provide:\n"
    "  • 'topic': the short label\n"
    "  • 'keywords': 3–4 example keywords\n"
    "  • 'indices': **list ALL integer indices** (0-based) of reviews that belong to that topic\n"
    "Please ensure that every review index appears at least once."
    "Respond in JSON with format:\n"
    "[\n"
    "  {\n"
    "    'topic': <label>,\n"
    "    'keywords': [ ... ],\n"
    "    'indices': [ ... ]\n"
    "  },\n"
    "  ... (total 5 objects)\n"
    "]\n"
    "Do not include any extra text."
)

# 3) Extract Topic using LLMs
topic_user = "Reviews:\n" + "\n---\n".join(docs)
resp_topics = ollama.chat(
    model='llama3',
    messages=[
        {'role':'system', 'content': topic_system},
        {'role':'user',   'content': topic_user}
    ]
)
topics = json.loads(resp_topics['message']['content'].strip())

# %%
docs[43]
# Out:
# 'The lunch special is an asbolute steal.'

# %%
topics[2]
# Out:
# {'topic': 'Atmosphere',
#  'keywords': ['ambiance', 'vibe', 'outdoor'],
#  'indices': [9, 19, 25, 26, 27]}

# %% [markdown]
# #### another way to parse strictly

# %%
# 4) prompt for sentiment analysis 
sentiment_system = (
    "You are a sentiment analysis assistant. "
    "Given a restaurant review, assign a sentiment score from -1 (very negative) to 1 (very positive). "
    "Respond with only the numerical score (e.g. 0.45 or -0.8), without any extra text."
)

# 5) measure Sentiment score using LLMs
sentiments = []
for idx, review in enumerate(docs):
    resp_sent = ollama.chat(
        model='llama3',
        messages=[
            {'role':'system', 'content': sentiment_system},
            {'role':'user',   'content': review}
        ]
    )
    # text → float 
    score = float(resp_sent['message']['content'].strip())
    sentiments.append(score)

# 6) 결과 DataFrame 구성
rows = []
for topic in topics:
    idxs = topic['indices']
    rows.append({
        'topic'     : topic['topic'],
        'keywords'  : ", ".join(topic['keywords']),
        'indices'   : idxs,
        'sentiments': [ round(sentiments[i], 3) for i in idxs ]
    })

df = pd.DataFrame(rows)
print(df.to_markdown(index=False))
# Out:
# | topic           | keywords                                   | indices                                 | sentiments                                                          |
# |:----------------|:-------------------------------------------|:----------------------------------------|:--------------------------------------------------------------------|
# | Food Quality    | pizza, filet, guacamole, shrimp, oysters   | [3, 5, 10, 12, 14, 16, 18, 20, 22, 24]  | [0.6, -0.6, 0.85, -0.7, 0.9, 0.75, 0.85, 0.95, 0.85, 0.75]          |
# | Service         | service, waiters, attentive, friendly      | [1, 2, 4, 6, 8, 11, 13, 15, 17, 21, 23] | [-0.6, 0.85, -0.85, 0.75, -0.83, -0.7, 0.4, -0.7, -0.7, -0.9, -0.9] |
# | Atmosphere      | ambiance, vibe, outdoor                    | [9, 19, 25, 26, 27]                     | [0.95, 0.85, 0.85, -0.9, 0.95]                                      |
# | Value           | affordable, great value, steal             | [7, 15, 20, 24, 28]                     | [0.95, -0.7, 0.95, 0.75, -0.8]                                      |
# | Dissatisfaction | disappointed, worst experience, nasty food | [4, 6, 14, 22, 26]                      | [-0.85, 0.75, 0.9, 0.85, -0.9]                                      |

# %% [markdown]
# - LDA relies only on word co-occurrence statistics
# - LDA Cannot automatically assign topic names
# - LLMs utilize semantic text representations
# - Can generate natural language topic names via prompting

# %%
import numpy as np

df['sentiment_mean'] = df['sentiments'].apply(np.mean)

# (선택) 소수점 3자리까지만 보기
df['sentiment_mean'] = df['sentiment_mean'].round(3)

# %%
df.head()
# Out:
#              topic                                    keywords  \
# 0     Food Quality    pizza, filet, guacamole, shrimp, oysters
# 1          Service       service, waiters, attentive, friendly
# 2       Atmosphere                     ambiance, vibe, outdoor
# 3            Value              affordable, great value, steal
# 4  Dissatisfaction  disappointed, worst experience, nasty food
#
#                                    indices  \
# 0   [3, 5, 10, 12, 14, 16, 18, 20, 22, 24]
# 1  [1, 2, 4, 6, 8, 11, 13, 15, 17, 21, 23]
# 2                      [9, 19, 25, 26, 27]
# 3                      [7, 15, 20, 24, 28]
# 4                       [4, 6, 14, 22, 26]
#
#                                           sentiments  sentiment_mean
# 0  [0.6, -0.6, 0.85, -0.7, 0.9, 0.75, 0.85, 0.95,...            0.52
# 1  [-0.6, 0.85, -0.85, 0.75, -0.83, -0.7, 0.4, -0...           -0.38
# 2                     [0.95, 0.85, 0.85, -0.9, 0.95]            0.54
# 3                     [0.95, -0.7, 0.95, 0.75, -0.8]            0.23
# 4                     [-0.85, 0.75, 0.9, 0.85, -0.9]            0.15

# %% [markdown]
# - Utilize with Dashboard
